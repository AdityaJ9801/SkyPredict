# %%
# !pip install -r rec.txt
# Out:
# Collecting numpy==1.19.5 (from -r rec.txt (line 1))
#   Using cached numpy-1.19.5.zip (7.3 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from -r rec.txt (line 2)) (2.2.2)
# Collecting matplotlib==3.3.4 (from -r rec.txt (line 3))
#   Using cached matplotlib-3.3.4.tar.gz (37.9 MB)
#   Preparing metadata (setup.py) ... done
# Collecting seaborn==0.11.1 (from -r rec.txt (line 4))
#   Using cached seaborn-0.11.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting scikit-learn==0.24.1 (from -r rec.txt (line 5))
#   Using cached scikit-learn-0.24.1.tar.gz (7.4 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting scipy==1.5.4 (from -r rec.txt (line 6))
#   Using cached scipy-1.5.4.tar.gz (25.2 MB)
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Installing build dependencies ... error
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# !pip install catboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.7)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
import scipy.stats as stats
from sklearn.model_selection import train_test_split
from collections import Counter
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
import joblib

# %%
df = pd.read_csv("processed_weather_data.csv")
pd.set_option("display.max_columns", None)
df
# Out:
#               Date Location   Temp  WindSpeed  Humidity RainToday RainTomorrow
# 0       2008-12-01   Albury  18.15       22.0      46.5        No           No
# 1       2008-12-02   Albury  16.25       13.0      34.5        No           No
# 2       2008-12-03   Albury  19.30       22.5      34.0        No           No
# 3       2008-12-04   Albury  18.60       10.0      30.5        No           No
# 4       2008-12-05   Albury  24.90       13.5      57.5        No           No
# ...            ...      ...    ...        ...       ...       ...          ...
# 145455  2017-06-21    Uluru  13.10       12.0      37.5        No           No
# 145456  2017-06-22    Uluru  14.45       11.0      38.5        No           No
# 145457  2017-06-23    Uluru  16.15        9.0      38.5        No           No
# 145458  2017-06-24    Uluru  17.40       10.0      37.5        No           No
# 145459  2017-06-25    Uluru  14.90       17.0      49.0        No          NaN
#
# [145460 rows x 7 columns]

# %%
numerical_feature = [feature for feature in df.columns if df[feature].dtypes != 'O']
discrete_feature=[feature for feature in numerical_feature if len(df[feature].unique())<25]
continuous_feature = [feature for feature in numerical_feature if feature not in discrete_feature]
categorical_feature = [feature for feature in df.columns if feature not in numerical_feature]
print("Numerical Features Count {}".format(len(numerical_feature)))
print("Discrete feature Count {}".format(len(discrete_feature)))
print("Continuous feature Count {}".format(len(continuous_feature)))
print("Categorical feature Count {}".format(len(categorical_feature)))
# Out:
# Numerical Features Count 3
# Discrete feature Count 0
# Continuous feature Count 3
# Categorical feature Count 4

# %%
# Handle Missing Values
df.isnull().sum()*100/len(df)
# Out:
# Date            0.000000
# Location        0.000000
# Temp            0.594665
# WindSpeed       0.833906
# Humidity        1.297264
# RainToday       2.241853
# RainTomorrow    2.245978
# dtype: float64

# %%
print(numerical_feature)
# Out:
# ['Temp', 'WindSpeed', 'Humidity']

# %%
def randomsampleimputation(df, variable):
    df[variable]=df[variable]
    random_sample=df[variable].dropna().sample(df[variable].isnull().sum(),random_state=0)
    random_sample.index=df[df[variable].isnull()].index
    df.loc[df[variable].isnull(),variable]=random_sample

# %%
df
# Out:
#               Date Location   Temp  WindSpeed  Humidity RainToday RainTomorrow
# 0       2008-12-01   Albury  18.15       22.0      46.5        No           No
# 1       2008-12-02   Albury  16.25       13.0      34.5        No           No
# 2       2008-12-03   Albury  19.30       22.5      34.0        No           No
# 3       2008-12-04   Albury  18.60       10.0      30.5        No           No
# 4       2008-12-05   Albury  24.90       13.5      57.5        No           No
# ...            ...      ...    ...        ...       ...       ...          ...
# 145455  2017-06-21    Uluru  13.10       12.0      37.5        No           No
# 145456  2017-06-22    Uluru  14.45       11.0      38.5        No           No
# 145457  2017-06-23    Uluru  16.15        9.0      38.5        No           No
# 145458  2017-06-24    Uluru  17.40       10.0      37.5        No           No
# 145459  2017-06-25    Uluru  14.90       17.0      49.0        No          NaN
#
# [145460 rows x 7 columns]

# %%
for feature in continuous_feature:
    data=df.copy()
    sns.distplot(df[feature])
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(feature)
    plt.figure(figsize=(15,15))
    plt.show()
# Out:
# <ipython-input-10-f3f36df57cc9>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])
# <ipython-input-10-f3f36df57cc9>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])
# <ipython-input-10-f3f36df57cc9>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])

# %%
#A for loop is used to plot a boxplot for all the continuous features to see the outliers
for feature in continuous_feature:
    data=df.copy()
    sns.boxplot(data[feature])
    plt.title(feature)
    plt.figure(figsize=(15,15))

# %%
for feature in continuous_feature:
    if(df[feature].isnull().sum()*100/len(df))>0:
        df[feature] = df[feature].fillna(df[feature].median())

# %%
df.isnull().sum()*100/len(df)
# Out:
# Date            0.000000
# Location        0.000000
# Temp            0.000000
# WindSpeed       0.000000
# Humidity        0.000000
# RainToday       2.241853
# RainTomorrow    2.245978
# dtype: float64

# %%
discrete_feature
# Out:
# []

# %%
def mode_nan(df,variable):
    mode=df[variable].value_counts().index[0]
    df[variable].fillna(mode,inplace=True)

# %%
df["RainToday"] = pd.get_dummies(df["RainToday"], drop_first = True)
df["RainTomorrow"] = pd.get_dummies(df["RainTomorrow"], drop_first = True)
df
# Out:
#               Date Location   Temp  WindSpeed  Humidity  RainToday  \
# 0       2008-12-01   Albury  18.15       22.0      46.5      False
# 1       2008-12-02   Albury  16.25       13.0      34.5      False
# 2       2008-12-03   Albury  19.30       22.5      34.0      False
# 3       2008-12-04   Albury  18.60       10.0      30.5      False
# 4       2008-12-05   Albury  24.90       13.5      57.5      False
# ...            ...      ...    ...        ...       ...        ...
# 145455  2017-06-21    Uluru  13.10       12.0      37.5      False
# 145456  2017-06-22    Uluru  14.45       11.0      38.5      False
# 145457  2017-06-23    Uluru  16.15        9.0      38.5      False
# 145458  2017-06-24    Uluru  17.40       10.0      37.5      False
# 145459  2017-06-25    Uluru  14.90       17.0      49.0      False
#
#         RainTomorrow
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# ...              ...
# 145455         False
# 145456         False
# 145457         False
# 145458         False
# 145459         False
#
# [145460 rows x 7 columns]

# %%
for feature in categorical_feature:
    print(feature, (df.groupby([feature])["RainTomorrow"].mean().sort_values(ascending = False)).index)
# Out:
# Date Index(['2007-11-01', '2007-12-15', '2008-02-03', '2008-01-31', '2008-01-30',
#        '2008-01-19', '2008-01-18', '2008-01-16', '2008-01-12', '2007-11-30',
#        ...
#        '2008-05-08', '2008-05-09', '2008-01-03', '2008-01-02', '2008-05-10',
#        '2008-05-11', '2008-05-12', '2008-05-13', '2008-05-14', '2007-12-25'],
#       dtype='object', name='Date', length=3436)
# Location Index(['Portland', 'Walpole', 'Cairns', 'Dartmoor', 'NorfolkIsland',
#        'MountGambier', 'Albany', 'Witchcliffe', 'CoffsHarbour', 'MountGinini',
#        'NorahHead', 'Darwin', 'Sydney', 'SydneyAirport', 'Ballarat',
#        'GoldCoast', 'Watsonia', 'Newcastle', 'Hobart', 'Wollongong',
#        'Williamtown', 'Launceston', 'Brisbane', 'MelbourneAirport', 'Adelaide',
#        'Sale', 'Albury', 'Perth', 'Melbourne', 'Nuriootpa', 'Penrith',
#        'BadgerysCreek', 'PerthAirport', 'Tuggeranong', 'Richmond', 'Bendigo',
#        'Canberra', 'WaggaWagga', 'Townsville', 'Katherine', 'PearceRAAF',
#        'SalmonGums', 'Nhil', 'Moree', 'Cobar', 'Mildura', 'AliceSprings',
#        'Uluru', 'Woomera'],
#       dtype='object', name='Location')
# RainToday Index([True, False], dtype='bool', name='RainToday')
# RainTomorrow Index([True, False], dtype='bool', name='RainTomorrow')

# %%
del(df["Location"])
df
# Out:
#               Date   Temp  WindSpeed  Humidity  RainToday  RainTomorrow
# 0       2008-12-01  18.15       22.0      46.5      False         False
# 1       2008-12-02  16.25       13.0      34.5      False         False
# 2       2008-12-03  19.30       22.5      34.0      False         False
# 3       2008-12-04  18.60       10.0      30.5      False         False
# 4       2008-12-05  24.90       13.5      57.5      False         False
# ...            ...    ...        ...       ...        ...           ...
# 145455  2017-06-21  13.10       12.0      37.5      False         False
# 145456  2017-06-22  14.45       11.0      38.5      False         False
# 145457  2017-06-23  16.15        9.0      38.5      False         False
# 145458  2017-06-24  17.40       10.0      37.5      False         False
# 145459  2017-06-25  14.90       17.0      49.0      False         False
#
# [145460 rows x 6 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day
df
# Out:
#              Date   Temp  WindSpeed  Humidity  RainToday  RainTomorrow  Month  \
# 0      2008-12-01  18.15       22.0      46.5      False         False     12
# 1      2008-12-02  16.25       13.0      34.5      False         False     12
# 2      2008-12-03  19.30       22.5      34.0      False         False     12
# 3      2008-12-04  18.60       10.0      30.5      False         False     12
# 4      2008-12-05  24.90       13.5      57.5      False         False     12
# ...           ...    ...        ...       ...        ...           ...    ...
# 145455 2017-06-21  13.10       12.0      37.5      False         False      6
# 145456 2017-06-22  14.45       11.0      38.5      False         False      6
# 145457 2017-06-23  16.15        9.0      38.5      False         False      6
# 145458 2017-06-24  17.40       10.0      37.5      False         False      6
# 145459 2017-06-25  14.90       17.0      49.0      False         False      6
#
#         Day
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5
# ...     ...
# 145455   21
# 145456   22
# 145457   23
# 145458   24
# 145459   25
#
# [145460 rows x 8 columns]

# %%
corrmat = df.corr()
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(corrmat,annot=True)

# %%
df
# Out:
#              Date   Temp  WindSpeed  Humidity  RainToday  RainTomorrow  Month  \
# 0      2008-12-01  18.15       22.0      46.5      False         False     12
# 1      2008-12-02  16.25       13.0      34.5      False         False     12
# 2      2008-12-03  19.30       22.5      34.0      False         False     12
# 3      2008-12-04  18.60       10.0      30.5      False         False     12
# 4      2008-12-05  24.90       13.5      57.5      False         False     12
# ...           ...    ...        ...       ...        ...           ...    ...
# 145455 2017-06-21  13.10       12.0      37.5      False         False      6
# 145456 2017-06-22  14.45       11.0      38.5      False         False      6
# 145457 2017-06-23  16.15        9.0      38.5      False         False      6
# 145458 2017-06-24  17.40       10.0      37.5      False         False      6
# 145459 2017-06-25  14.90       17.0      49.0      False         False      6
#
#         Day
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5
# ...     ...
# 145455   21
# 145456   22
# 145457   23
# 145458   24
# 145459   25
#
# [145460 rows x 8 columns]

# %%
for feature in continuous_feature:
    data=df.copy()
    sns.boxplot(data[feature])
    plt.title(feature)
    plt.figure(figsize=(15,15))

# %%
for feature in continuous_feature:
    print(feature)
# Out:
# Temp
# WindSpeed
# Humidity

# %%
IQR=df.Temp.quantile(0.75)-df.Temp.quantile(0.25)
lower_bridge=df.Temp.quantile(0.25)-(IQR*1.5)
upper_bridge=df.Temp.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -0.9500000000000011 36.25

# %%
df.loc[df['Temp']>=36.975,'Temp']=36.975
df.loc[df['Temp']<=2.7,'Temp']=2.7

# %%
IQR=df.WindSpeed.quantile(0.75)-df.WindSpeed.quantile(0.25)
lower_bridge=df.WindSpeed.quantile(0.25)-(IQR*1.5)
upper_bridge=df.WindSpeed.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -3.25 34.75

# %%
df.loc[df['WindSpeed']>=38.75,'WindSpeed']=38.75
df.loc[df['WindSpeed']<=-7.25,'WindSpeed']=-7.25

# %%
IQR=df.Humidity.quantile(0.75)-df.Humidity.quantile(0.25)
lower_bridge=df.Humidity.quantile(0.25)-(IQR*1.5)
upper_bridge=df.Humidity.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 13.0 109.0

# %%
df.loc[df['Humidity']>=122,'Humidity']=122
df.loc[df['Humidity']<=18,'Humidity']=18

# %%
for feature in continuous_feature:
    data=df.copy()
    sns.boxplot(data[feature])
    plt.title(feature)
    plt.figure(figsize=(15,15))

# %%
def qq_plots(df, variable):
    plt.figure(figsize=(15,6))
    plt.subplot(1, 2, 1)
    df[variable].hist()
    plt.subplot(1, 2, 2)
    stats.probplot(df[variable], dist="norm", plot=plt)
    plt.show()

# %%
for feature in continuous_feature:
    print(feature)
    plt.figure(figsize=(15,6))
    plt.subplot(1, 2, 1)
    df[feature].hist()
    plt.subplot(1, 2, 2)
    stats.probplot(df[feature], dist="norm", plot=plt)
    plt.show()
# Out:
# Temp
# WindSpeed
# Humidity

# %%
df.to_csv("preprocessed_1.csv", index=False)

# %%
X = df.drop(["RainTomorrow", "Date"], axis=1)
Y = df["RainTomorrow"]

# %%
# scaler = RobustScaler()
# X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size =0.2, stratify = Y, random_state = 0)

# %%
X_train
# Out:
#          Temp  WindSpeed  Humidity  RainToday  Month  Day
# 43447   14.50       16.0      48.0      False      6   19
# 140904  27.15       24.0      51.0      False      8   26
# 54615   20.80       19.5      39.5      False      2   25
# 109793  15.90       17.5      68.5       True      5    6
# 74462   21.95       26.5      51.0      False      1   25
# ...       ...        ...       ...        ...    ...  ...
# 106567  20.85       18.5      32.5      False     11    2
# 52791    7.25       25.0      99.0       True     11   30
# 56339    5.15       27.0      76.5      False      5   21
# 82299    9.00       21.0      87.5       True      8   24
# 115175  12.50       15.5      78.0      False      7   10
#
# [116368 rows x 6 columns]

# %%
y_train
# Out:
# 43447     False
# 140904    False
# 54615     False
# 109793    False
# 74462     False
#           ...
# 106567    False
# 52791      True
# 56339     False
# 82299      True
# 115175    False
# Name: RainTomorrow, Length: 116368, dtype: bool

# %%
sm=SMOTE(random_state=0)
X_train_res, y_train_res = sm.fit_resample(X_train, y_train)
print("The number of classes before fit {}".format(Counter(y_train)))
print("The number of classes after fit {}".format(Counter(y_train_res)))
# Out:
# The number of classes before fit Counter({False: 90866, True: 25502})
# The number of classes after fit Counter({False: 90866, True: 90866})

# %%
cat = CatBoostClassifier(iterations=2000, eval_metric = "AUC")
cat.fit(X_train_res, y_train_res)
# Out:
# Learning rate set to 0.050311
# 0:	total: 108ms	remaining: 3m 36s
# 1:	total: 164ms	remaining: 2m 44s
# 2:	total: 217ms	remaining: 2m 24s
# 3:	total: 257ms	remaining: 2m 8s
# 4:	total: 291ms	remaining: 1m 56s
# 5:	total: 338ms	remaining: 1m 52s
# 6:	total: 390ms	remaining: 1m 51s
# 7:	total: 435ms	remaining: 1m 48s
# 8:	total: 471ms	remaining: 1m 44s
# 9:	total: 509ms	remaining: 1m 41s
# 10:	total: 550ms	remaining: 1m 39s
# 11:	total: 589ms	remaining: 1m 37s
# 12:	total: 624ms	remaining: 1m 35s
# 13:	total: 676ms	remaining: 1m 35s
# 14:	total: 714ms	remaining: 1m 34s
# 15:	total: 755ms	remaining: 1m 33s
# 16:	total: 795ms	remaining: 1m 32s
# 17:	total: 832ms	remaining: 1m 31s
# 18:	total: 867ms	remaining: 1m 30s
# 19:	total: 917ms	remaining: 1m 30s
# 20:	total: 972ms	remaining: 1m 31s
# 21:	total: 1.01s	remaining: 1m 30s
# 22:	total: 1.05s	remaining: 1m 30s
# 23:	total: 1.09s	remaining: 1m 29s
# 24:	total: 1.13s	remaining: 1m 29s
# 25:	total: 1.18s	remaining: 1m 29s
# 26:	total: 1.23s	remaining: 1m 30s
# 27:	total: 1.31s	remaining: 1m 32s
# 28:	total: 1.39s	remaining: 1m 34s
# 29:	total: 1.49s	remaining: 1m 37s
# 30:	total: 1.54s	remaining: 1m 37s
# 31:	total: 1.6s	remaining: 1m 38s
# 32:	total: 1.67s	remaining: 1m 39s
# 33:	total: 1.76s	remaining: 1m 41s
# 34:	total: 1.86s	remaining: 1m 44s
# 35:	total: 1.98s	remaining: 1m 47s
# 36:	total: 2.05s	remaining: 1m 49s
# 37:	total: 2.15s	remaining: 1m 50s
# 38:	total: 2.23s	remaining: 1m 52s
# 39:	total: 2.32s	remaining: 1m 53s
# 40:	total: 2.42s	remaining: 1m 55s
# 41:	total: 2.52s	remaining: 1m 57s
# 42:	total: 2.61s	remaining: 1m 58s
# 43:	total: 2.71s	remaining: 2m
# 44:	total: 2.81s	remaining: 2m 1s
# 45:	total: 2.88s	remaining: 2m 2s
# 46:	total: 2.94s	remaining: 2m 2s
# 47:	total: 3.03s	remaining: 2m 3s
# 48:	total: 3.12s	remaining: 2m 4s
# 49:	total: 3.21s	remaining: 2m 5s
# 50:	total: 3.29s	remaining: 2m 5s
# 51:	total: 3.38s	remaining: 2m 6s
# 52:	total: 3.47s	remaining: 2m 7s
# 53:	total: 3.55s	remaining: 2m 8s
# 54:	total: 3.63s	remaining: 2m 8s
# 55:	total: 3.71s	remaining: 2m 8s
# 56:	total: 3.81s	remaining: 2m 9s
# 57:	total: 3.88s	remaining: 2m 10s
# 58:	total: 3.95s	remaining: 2m 9s
# 59:	total: 4.04s	remaining: 2m 10s
# 60:	total: 4.13s	remaining: 2m 11s
# 61:	total: 4.22s	remaining: 2m 11s
# 62:	total: 4.31s	remaining: 2m 12s
# 63:	total: 4.41s	remaining: 2m 13s
# 64:	total: 4.5s	remaining: 2m 14s
# 65:	total: 4.61s	remaining: 2m 15s
# 66:	total: 4.72s	remaining: 2m 16s
# 67:	total: 4.79s	remaining: 2m 15s
# 68:	total: 4.89s	remaining: 2m 16s
# 69:	total: 4.96s	remaining: 2m 16s
# 70:	total: 5.06s	remaining: 2m 17s
# 71:	total: 5.14s	remaining: 2m 17s
# 72:	total: 5.24s	remaining: 2m 18s
# 73:	total: 5.34s	remaining: 2m 18s
# 74:	total: 5.44s	remaining: 2m 19s
# 75:	total: 5.5s	remaining: 2m 19s
# 76:	total: 5.54s	remaining: 2m 18s
# 77:	total: 5.58s	remaining: 2m 17s
# 78:	total: 5.64s	remaining: 2m 17s
# 79:	total: 5.69s	remaining: 2m 16s
# 80:	total: 5.74s	remaining: 2m 16s
# 81:	total: 5.79s	remaining: 2m 15s
# 82:	total: 5.83s	remaining: 2m 14s
# 83:	total: 5.88s	remaining: 2m 14s
# 84:	total: 5.93s	remaining: 2m 13s
# 85:	total: 5.98s	remaining: 2m 13s
# 86:	total: 6.02s	remaining: 2m 12s
# 87:	total: 6.06s	remaining: 2m 11s
# 88:	total: 6.11s	remaining: 2m 11s
# 89:	total: 6.15s	remaining: 2m 10s
# 90:	total: 6.2s	remaining: 2m 10s
# 91:	total: 6.24s	remaining: 2m 9s
# 92:	total: 6.29s	remaining: 2m 8s
# 93:	total: 6.33s	remaining: 2m 8s
# 94:	total: 6.37s	remaining: 2m 7s
# 95:	total: 6.41s	remaining: 2m 7s
# 96:	total: 6.45s	remaining: 2m 6s
# 97:	total: 6.49s	remaining: 2m 5s
# 98:	total: 6.53s	remaining: 2m 5s
# 99:	total: 6.57s	remaining: 2m 4s
# 100:	total: 6.61s	remaining: 2m 4s
# 101:	total: 6.66s	remaining: 2m 3s
# 102:	total: 6.71s	remaining: 2m 3s
# 103:	total: 6.75s	remaining: 2m 3s
# 104:	total: 6.8s	remaining: 2m 2s
# 105:	total: 6.84s	remaining: 2m 2s
# 106:	total: 6.89s	remaining: 2m 1s
# 107:	total: 6.93s	remaining: 2m 1s
# 108:	total: 6.97s	remaining: 2m
# 109:	total: 7.02s	remaining: 2m
# 110:	total: 7.06s	remaining: 2m
# 111:	total: 7.11s	remaining: 1m 59s
# 112:	total: 7.15s	remaining: 1m 59s
# 113:	total: 7.18s	remaining: 1m 58s
# 114:	total: 7.22s	remaining: 1m 58s
# 115:	total: 7.28s	remaining: 1m 58s
# 116:	total: 7.32s	remaining: 1m 57s
# 117:	total: 7.36s	remaining: 1m 57s
# 118:	total: 7.4s	remaining: 1m 57s
# 119:	total: 7.44s	remaining: 1m 56s
# 120:	total: 7.49s	remaining: 1m 56s
# 121:	total: 7.53s	remaining: 1m 55s
# 122:	total: 7.57s	remaining: 1m 55s
# 123:	total: 7.62s	remaining: 1m 55s
# 124:	total: 7.66s	remaining: 1m 54s
# 125:	total: 7.72s	remaining: 1m 54s
# 126:	total: 7.76s	remaining: 1m 54s
# 127:	total: 7.82s	remaining: 1m 54s
# 128:	total: 7.86s	remaining: 1m 53s
# 129:	total: 7.92s	remaining: 1m 53s
# 130:	total: 7.96s	remaining: 1m 53s
# 131:	total: 8s	remaining: 1m 53s
# 132:	total: 8.05s	remaining: 1m 52s
# 133:	total: 8.09s	remaining: 1m 52s
# 134:	total: 8.13s	remaining: 1m 52s
# 135:	total: 8.18s	remaining: 1m 52s
# 136:	total: 8.22s	remaining: 1m 51s
# 137:	total: 8.27s	remaining: 1m 51s
# 138:	total: 8.31s	remaining: 1m 51s
# 139:	total: 8.35s	remaining: 1m 50s
# 140:	total: 8.4s	remaining: 1m 50s
# 141:	total: 8.45s	remaining: 1m 50s
# 142:	total: 8.49s	remaining: 1m 50s
# 143:	total: 8.53s	remaining: 1m 49s
# 144:	total: 8.57s	remaining: 1m 49s
# 145:	total: 8.62s	remaining: 1m 49s
# 146:	total: 8.66s	remaining: 1m 49s
# 147:	total: 8.71s	remaining: 1m 48s
# 148:	total: 8.76s	remaining: 1m 48s
# 149:	total: 8.81s	remaining: 1m 48s
# 150:	total: 8.87s	remaining: 1m 48s
# 151:	total: 8.92s	remaining: 1m 48s
# 152:	total: 8.96s	remaining: 1m 48s
# 153:	total: 9.01s	remaining: 1m 48s
# 154:	total: 9.08s	remaining: 1m 48s
# 155:	total: 9.12s	remaining: 1m 47s
# 156:	total: 9.17s	remaining: 1m 47s
# 157:	total: 9.21s	remaining: 1m 47s
# 158:	total: 9.26s	remaining: 1m 47s
# 159:	total: 9.29s	remaining: 1m 46s
# 160:	total: 9.35s	remaining: 1m 46s
# 161:	total: 9.39s	remaining: 1m 46s
# 162:	total: 9.43s	remaining: 1m 46s
# 163:	total: 9.46s	remaining: 1m 45s
# 164:	total: 9.52s	remaining: 1m 45s
# 165:	total: 9.58s	remaining: 1m 45s
# 166:	total: 9.62s	remaining: 1m 45s
# 167:	total: 9.66s	remaining: 1m 45s
# 168:	total: 9.7s	remaining: 1m 45s
# 169:	total: 9.77s	remaining: 1m 45s
# 170:	total: 9.82s	remaining: 1m 45s
# 171:	total: 9.88s	remaining: 1m 45s
# 172:	total: 9.93s	remaining: 1m 44s
# 173:	total: 9.99s	remaining: 1m 44s
# 174:	total: 10s	remaining: 1m 44s
# 175:	total: 10.1s	remaining: 1m 44s
# 176:	total: 10.1s	remaining: 1m 44s
# 177:	total: 10.2s	remaining: 1m 44s
# 178:	total: 10.2s	remaining: 1m 43s
# 179:	total: 10.3s	remaining: 1m 43s
# 180:	total: 10.3s	remaining: 1m 43s
# 181:	total: 10.3s	remaining: 1m 43s
# 182:	total: 10.4s	remaining: 1m 43s
# 183:	total: 10.4s	remaining: 1m 43s
# 184:	total: 10.5s	remaining: 1m 42s
# 185:	total: 10.5s	remaining: 1m 42s
# 186:	total: 10.6s	remaining: 1m 42s
# 187:	total: 10.6s	remaining: 1m 42s
# 188:	total: 10.7s	remaining: 1m 42s
# 189:	total: 10.7s	remaining: 1m 42s
# 190:	total: 10.8s	remaining: 1m 41s
# 191:	total: 10.8s	remaining: 1m 41s
# 192:	total: 10.9s	remaining: 1m 41s
# 193:	total: 10.9s	remaining: 1m 41s
# 194:	total: 11s	remaining: 1m 41s
# 195:	total: 11s	remaining: 1m 41s
# 196:	total: 11.1s	remaining: 1m 41s
# 197:	total: 11.1s	remaining: 1m 41s
# 198:	total: 11.2s	remaining: 1m 41s
# 199:	total: 11.2s	remaining: 1m 41s
# 200:	total: 11.3s	remaining: 1m 40s
# 201:	total: 11.3s	remaining: 1m 40s
# 202:	total: 11.4s	remaining: 1m 40s
# 203:	total: 11.4s	remaining: 1m 40s
# 204:	total: 11.5s	remaining: 1m 40s
# 205:	total: 11.5s	remaining: 1m 40s
# 206:	total: 11.6s	remaining: 1m 40s
# 207:	total: 11.6s	remaining: 1m 40s
# 208:	total: 11.7s	remaining: 1m 40s
# 209:	total: 11.7s	remaining: 1m 40s
# 210:	total: 11.8s	remaining: 1m 39s
# 211:	total: 11.9s	remaining: 1m 40s
# 212:	total: 11.9s	remaining: 1m 40s
# 213:	total: 12s	remaining: 1m 39s
# 214:	total: 12s	remaining: 1m 39s
# 215:	total: 12.1s	remaining: 1m 39s
# 216:	total: 12.1s	remaining: 1m 39s
# 217:	total: 12.2s	remaining: 1m 39s
# 218:	total: 12.2s	remaining: 1m 39s
# 219:	total: 12.3s	remaining: 1m 39s
# 220:	total: 12.3s	remaining: 1m 39s
# 221:	total: 12.4s	remaining: 1m 39s
# 222:	total: 12.4s	remaining: 1m 38s
# 223:	total: 12.5s	remaining: 1m 38s
# 224:	total: 12.5s	remaining: 1m 38s
# 225:	total: 12.6s	remaining: 1m 38s
# 226:	total: 12.6s	remaining: 1m 38s
# 227:	total: 12.7s	remaining: 1m 38s
# 228:	total: 12.7s	remaining: 1m 38s
# 229:	total: 12.7s	remaining: 1m 38s
# 230:	total: 12.8s	remaining: 1m 37s
# 231:	total: 12.9s	remaining: 1m 38s
# 232:	total: 12.9s	remaining: 1m 38s
# 233:	total: 13s	remaining: 1m 37s
# 234:	total: 13s	remaining: 1m 37s
# 235:	total: 13.1s	remaining: 1m 37s
# 236:	total: 13.1s	remaining: 1m 37s
# 237:	total: 13.2s	remaining: 1m 37s
# 238:	total: 13.2s	remaining: 1m 37s
# 239:	total: 13.3s	remaining: 1m 37s
# 240:	total: 13.3s	remaining: 1m 37s
# 241:	total: 13.4s	remaining: 1m 37s
# 242:	total: 13.4s	remaining: 1m 36s
# 243:	total: 13.5s	remaining: 1m 36s
# 244:	total: 13.5s	remaining: 1m 36s
# 245:	total: 13.6s	remaining: 1m 36s
# 246:	total: 13.6s	remaining: 1m 36s
# 247:	total: 13.7s	remaining: 1m 36s
# 248:	total: 13.7s	remaining: 1m 36s
# 249:	total: 13.8s	remaining: 1m 36s
# 250:	total: 13.8s	remaining: 1m 36s
# 251:	total: 13.9s	remaining: 1m 36s
# 252:	total: 13.9s	remaining: 1m 36s
# 253:	total: 14s	remaining: 1m 35s
# 254:	total: 14s	remaining: 1m 35s
# 255:	total: 14s	remaining: 1m 35s
# 256:	total: 14.1s	remaining: 1m 35s
# 257:	total: 14.1s	remaining: 1m 35s
# 258:	total: 14.2s	remaining: 1m 35s
# 259:	total: 14.2s	remaining: 1m 35s
# 260:	total: 14.2s	remaining: 1m 34s
# 261:	total: 14.3s	remaining: 1m 34s
# 262:	total: 14.3s	remaining: 1m 34s
# 263:	total: 14.4s	remaining: 1m 34s
# 264:	total: 14.4s	remaining: 1m 34s
# 265:	total: 14.4s	remaining: 1m 34s
# 266:	total: 14.5s	remaining: 1m 33s
# 267:	total: 14.5s	remaining: 1m 33s
# 268:	total: 14.6s	remaining: 1m 33s
# 269:	total: 14.6s	remaining: 1m 33s
# 270:	total: 14.6s	remaining: 1m 33s
# 271:	total: 14.7s	remaining: 1m 33s
# 272:	total: 14.7s	remaining: 1m 33s
# 273:	total: 14.8s	remaining: 1m 32s
# 274:	total: 14.8s	remaining: 1m 32s
# 275:	total: 14.8s	remaining: 1m 32s
# 276:	total: 14.9s	remaining: 1m 32s
# 277:	total: 14.9s	remaining: 1m 32s
# 278:	total: 15s	remaining: 1m 32s
# 279:	total: 15s	remaining: 1m 32s
# 280:	total: 15.1s	remaining: 1m 32s
# 281:	total: 15.1s	remaining: 1m 32s
# 282:	total: 15.2s	remaining: 1m 31s
# 283:	total: 15.2s	remaining: 1m 31s
# 284:	total: 15.2s	remaining: 1m 31s
# 285:	total: 15.3s	remaining: 1m 31s
# 286:	total: 15.3s	remaining: 1m 31s
# 287:	total: 15.4s	remaining: 1m 31s
# 288:	total: 15.4s	remaining: 1m 31s
# 289:	total: 15.5s	remaining: 1m 31s
# 290:	total: 15.6s	remaining: 1m 31s
# 291:	total: 15.6s	remaining: 1m 31s
# 292:	total: 15.7s	remaining: 1m 31s
# 293:	total: 15.8s	remaining: 1m 31s
# 294:	total: 15.9s	remaining: 1m 32s
# 295:	total: 16s	remaining: 1m 32s
# 296:	total: 16.1s	remaining: 1m 32s
# 297:	total: 16.2s	remaining: 1m 32s
# 298:	total: 16.3s	remaining: 1m 32s
# 299:	total: 16.4s	remaining: 1m 33s
# 300:	total: 16.5s	remaining: 1m 33s
# 301:	total: 16.6s	remaining: 1m 33s
# 302:	total: 16.7s	remaining: 1m 33s
# 303:	total: 16.8s	remaining: 1m 33s
# 304:	total: 16.9s	remaining: 1m 34s
# 305:	total: 17s	remaining: 1m 34s
# 306:	total: 17.1s	remaining: 1m 34s
# 307:	total: 17.2s	remaining: 1m 34s
# 308:	total: 17.3s	remaining: 1m 34s
# 309:	total: 17.4s	remaining: 1m 34s
# 310:	total: 17.5s	remaining: 1m 34s
# 311:	total: 17.5s	remaining: 1m 34s
# 312:	total: 17.6s	remaining: 1m 35s
# 313:	total: 17.7s	remaining: 1m 35s
# 314:	total: 17.8s	remaining: 1m 35s
# 315:	total: 17.9s	remaining: 1m 35s
# 316:	total: 18s	remaining: 1m 35s
# 317:	total: 18.1s	remaining: 1m 35s
# 318:	total: 18.2s	remaining: 1m 35s
# 319:	total: 18.3s	remaining: 1m 35s
# 320:	total: 18.4s	remaining: 1m 36s
# 321:	total: 18.5s	remaining: 1m 36s
# 322:	total: 18.6s	remaining: 1m 36s
# 323:	total: 18.7s	remaining: 1m 36s
# 324:	total: 18.8s	remaining: 1m 36s
# 325:	total: 18.8s	remaining: 1m 36s
# 326:	total: 18.9s	remaining: 1m 36s
# 327:	total: 19s	remaining: 1m 37s
# 328:	total: 19.1s	remaining: 1m 37s
# 329:	total: 19.2s	remaining: 1m 37s
# 330:	total: 19.3s	remaining: 1m 37s
# 331:	total: 19.4s	remaining: 1m 37s
# 332:	total: 19.5s	remaining: 1m 37s
# 333:	total: 19.5s	remaining: 1m 37s
# 334:	total: 19.6s	remaining: 1m 37s
# 335:	total: 19.6s	remaining: 1m 37s
# 336:	total: 19.6s	remaining: 1m 36s
# 337:	total: 19.7s	remaining: 1m 36s
# 338:	total: 19.7s	remaining: 1m 36s
# 339:	total: 19.7s	remaining: 1m 36s
# 340:	total: 19.8s	remaining: 1m 36s
# 341:	total: 19.8s	remaining: 1m 36s
# 342:	total: 19.9s	remaining: 1m 36s
# 343:	total: 19.9s	remaining: 1m 35s
# 344:	total: 20s	remaining: 1m 35s
# 345:	total: 20s	remaining: 1m 35s
# 346:	total: 20.1s	remaining: 1m 35s
# 347:	total: 20.1s	remaining: 1m 35s
# 348:	total: 20.2s	remaining: 1m 35s
# 349:	total: 20.2s	remaining: 1m 35s
# 350:	total: 20.2s	remaining: 1m 35s
# 351:	total: 20.3s	remaining: 1m 34s
# 352:	total: 20.3s	remaining: 1m 34s
# 353:	total: 20.3s	remaining: 1m 34s
# 354:	total: 20.4s	remaining: 1m 34s
# 355:	total: 20.4s	remaining: 1m 34s
# 356:	total: 20.5s	remaining: 1m 34s
# 357:	total: 20.5s	remaining: 1m 34s
# 358:	total: 20.6s	remaining: 1m 33s
# 359:	total: 20.6s	remaining: 1m 33s
# 360:	total: 20.6s	remaining: 1m 33s
# 361:	total: 20.7s	remaining: 1m 33s
# 362:	total: 20.7s	remaining: 1m 33s
# 363:	total: 20.7s	remaining: 1m 33s
# 364:	total: 20.8s	remaining: 1m 33s
# 365:	total: 20.8s	remaining: 1m 33s
# 366:	total: 20.9s	remaining: 1m 32s
# 367:	total: 20.9s	remaining: 1m 32s
# 368:	total: 20.9s	remaining: 1m 32s
# 369:	total: 21s	remaining: 1m 32s
# 370:	total: 21s	remaining: 1m 32s
# 371:	total: 21.1s	remaining: 1m 32s
# 372:	total: 21.1s	remaining: 1m 32s
# 373:	total: 21.2s	remaining: 1m 32s
# 374:	total: 21.2s	remaining: 1m 31s
# 375:	total: 21.2s	remaining: 1m 31s
# 376:	total: 21.3s	remaining: 1m 31s
# 377:	total: 21.3s	remaining: 1m 31s
# 378:	total: 21.4s	remaining: 1m 31s
# 379:	total: 21.4s	remaining: 1m 31s
# 380:	total: 21.4s	remaining: 1m 31s
# 381:	total: 21.5s	remaining: 1m 30s
# 382:	total: 21.5s	remaining: 1m 30s
# 383:	total: 21.6s	remaining: 1m 30s
# 384:	total: 21.6s	remaining: 1m 30s
# 385:	total: 21.6s	remaining: 1m 30s
# 386:	total: 21.7s	remaining: 1m 30s
# 387:	total: 21.7s	remaining: 1m 30s
# 388:	total: 21.8s	remaining: 1m 30s
# 389:	total: 21.8s	remaining: 1m 30s
# 390:	total: 21.8s	remaining: 1m 29s
# 391:	total: 21.9s	remaining: 1m 29s
# 392:	total: 21.9s	remaining: 1m 29s
# 393:	total: 22s	remaining: 1m 29s
# 394:	total: 22s	remaining: 1m 29s
# 395:	total: 22.1s	remaining: 1m 29s
# 396:	total: 22.1s	remaining: 1m 29s
# 397:	total: 22.1s	remaining: 1m 29s
# 398:	total: 22.2s	remaining: 1m 29s
# 399:	total: 22.2s	remaining: 1m 28s
# 400:	total: 22.3s	remaining: 1m 28s
# 401:	total: 22.3s	remaining: 1m 28s
# 402:	total: 22.3s	remaining: 1m 28s
# 403:	total: 22.4s	remaining: 1m 28s
# 404:	total: 22.4s	remaining: 1m 28s
# 405:	total: 22.5s	remaining: 1m 28s
# 406:	total: 22.5s	remaining: 1m 28s
# 407:	total: 22.5s	remaining: 1m 27s
# 408:	total: 22.6s	remaining: 1m 27s
# 409:	total: 22.6s	remaining: 1m 27s
# 410:	total: 22.7s	remaining: 1m 27s
# 411:	total: 22.7s	remaining: 1m 27s
# 412:	total: 22.8s	remaining: 1m 27s
# 413:	total: 22.8s	remaining: 1m 27s
# 414:	total: 22.8s	remaining: 1m 27s
# 415:	total: 22.9s	remaining: 1m 27s
# 416:	total: 22.9s	remaining: 1m 27s
# 417:	total: 23s	remaining: 1m 26s
# 418:	total: 23s	remaining: 1m 26s
# 419:	total: 23.1s	remaining: 1m 26s
# 420:	total: 23.1s	remaining: 1m 26s
# 421:	total: 23.1s	remaining: 1m 26s
# 422:	total: 23.2s	remaining: 1m 26s
# 423:	total: 23.2s	remaining: 1m 26s
# 424:	total: 23.3s	remaining: 1m 26s
# 425:	total: 23.3s	remaining: 1m 26s
# 426:	total: 23.3s	remaining: 1m 25s
# 427:	total: 23.4s	remaining: 1m 25s
# 428:	total: 23.4s	remaining: 1m 25s
# 429:	total: 23.5s	remaining: 1m 25s
# 430:	total: 23.5s	remaining: 1m 25s
# 431:	total: 23.5s	remaining: 1m 25s
# 432:	total: 23.6s	remaining: 1m 25s
# 433:	total: 23.6s	remaining: 1m 25s
# 434:	total: 23.7s	remaining: 1m 25s
# 435:	total: 23.7s	remaining: 1m 25s
# 436:	total: 23.8s	remaining: 1m 24s
# 437:	total: 23.8s	remaining: 1m 24s
# 438:	total: 23.8s	remaining: 1m 24s
# 439:	total: 23.9s	remaining: 1m 24s
# 440:	total: 23.9s	remaining: 1m 24s
# 441:	total: 24s	remaining: 1m 24s
# 442:	total: 24s	remaining: 1m 24s
# 443:	total: 24s	remaining: 1m 24s
# 444:	total: 24.1s	remaining: 1m 24s
# 445:	total: 24.1s	remaining: 1m 24s
# 446:	total: 24.2s	remaining: 1m 23s
# 447:	total: 24.2s	remaining: 1m 23s
# 448:	total: 24.3s	remaining: 1m 23s
# 449:	total: 24.3s	remaining: 1m 23s
# 450:	total: 24.3s	remaining: 1m 23s
# 451:	total: 24.4s	remaining: 1m 23s
# 452:	total: 24.4s	remaining: 1m 23s
# 453:	total: 24.5s	remaining: 1m 23s
# 454:	total: 24.5s	remaining: 1m 23s
# 455:	total: 24.5s	remaining: 1m 23s
# 456:	total: 24.6s	remaining: 1m 22s
# 457:	total: 24.6s	remaining: 1m 22s
# 458:	total: 24.7s	remaining: 1m 22s
# 459:	total: 24.7s	remaining: 1m 22s
# 460:	total: 24.7s	remaining: 1m 22s
# 461:	total: 24.8s	remaining: 1m 22s
# 462:	total: 24.8s	remaining: 1m 22s
# 463:	total: 24.9s	remaining: 1m 22s
# 464:	total: 24.9s	remaining: 1m 22s
# 465:	total: 24.9s	remaining: 1m 22s
# 466:	total: 25s	remaining: 1m 22s
# 467:	total: 25s	remaining: 1m 21s
# 468:	total: 25.1s	remaining: 1m 21s
# 469:	total: 25.1s	remaining: 1m 21s
# 470:	total: 25.2s	remaining: 1m 21s
# 471:	total: 25.2s	remaining: 1m 21s
# 472:	total: 25.3s	remaining: 1m 21s
# 473:	total: 25.3s	remaining: 1m 21s
# 474:	total: 25.3s	remaining: 1m 21s
# 475:	total: 25.4s	remaining: 1m 21s
# 476:	total: 25.4s	remaining: 1m 21s
# 477:	total: 25.4s	remaining: 1m 21s
# 478:	total: 25.5s	remaining: 1m 20s
# 479:	total: 25.5s	remaining: 1m 20s
# 480:	total: 25.6s	remaining: 1m 20s
# 481:	total: 25.6s	remaining: 1m 20s
# 482:	total: 25.6s	remaining: 1m 20s
# 483:	total: 25.7s	remaining: 1m 20s
# 484:	total: 25.7s	remaining: 1m 20s
# 485:	total: 25.8s	remaining: 1m 20s
# 486:	total: 25.8s	remaining: 1m 20s
# 487:	total: 25.9s	remaining: 1m 20s
# 488:	total: 25.9s	remaining: 1m 20s
# 489:	total: 25.9s	remaining: 1m 19s
# 490:	total: 26s	remaining: 1m 19s
# 491:	total: 26s	remaining: 1m 19s
# 492:	total: 26.1s	remaining: 1m 19s
# 493:	total: 26.1s	remaining: 1m 19s
# 494:	total: 26.1s	remaining: 1m 19s
# 495:	total: 26.2s	remaining: 1m 19s
# 496:	total: 26.2s	remaining: 1m 19s
# 497:	total: 26.3s	remaining: 1m 19s
# 498:	total: 26.3s	remaining: 1m 19s
# 499:	total: 26.3s	remaining: 1m 19s
# 500:	total: 26.4s	remaining: 1m 18s
# 501:	total: 26.4s	remaining: 1m 18s
# 502:	total: 26.5s	remaining: 1m 18s
# 503:	total: 26.5s	remaining: 1m 18s
# 504:	total: 26.5s	remaining: 1m 18s
# 505:	total: 26.6s	remaining: 1m 18s
# 506:	total: 26.6s	remaining: 1m 18s
# 507:	total: 26.7s	remaining: 1m 18s
# 508:	total: 26.7s	remaining: 1m 18s
# 509:	total: 26.8s	remaining: 1m 18s
# 510:	total: 26.8s	remaining: 1m 18s
# 511:	total: 26.8s	remaining: 1m 17s
# 512:	total: 26.9s	remaining: 1m 17s
# 513:	total: 26.9s	remaining: 1m 17s
# 514:	total: 27s	remaining: 1m 17s
# 515:	total: 27s	remaining: 1m 17s
# 516:	total: 27s	remaining: 1m 17s
# 517:	total: 27.1s	remaining: 1m 17s
# 518:	total: 27.1s	remaining: 1m 17s
# 519:	total: 27.1s	remaining: 1m 17s
# 520:	total: 27.2s	remaining: 1m 17s
# 521:	total: 27.2s	remaining: 1m 17s
# 522:	total: 27.3s	remaining: 1m 16s
# 523:	total: 27.3s	remaining: 1m 16s
# 524:	total: 27.4s	remaining: 1m 16s
# 525:	total: 27.4s	remaining: 1m 16s
# 526:	total: 27.4s	remaining: 1m 16s
# 527:	total: 27.5s	remaining: 1m 16s
# 528:	total: 27.5s	remaining: 1m 16s
# 529:	total: 27.6s	remaining: 1m 16s
# 530:	total: 27.6s	remaining: 1m 16s
# 531:	total: 27.6s	remaining: 1m 16s
# 532:	total: 27.7s	remaining: 1m 16s
# 533:	total: 27.7s	remaining: 1m 16s
# 534:	total: 27.8s	remaining: 1m 16s
# 535:	total: 27.8s	remaining: 1m 15s
# 536:	total: 27.8s	remaining: 1m 15s
# 537:	total: 27.9s	remaining: 1m 15s
# 538:	total: 27.9s	remaining: 1m 15s
# 539:	total: 28s	remaining: 1m 15s
# 540:	total: 28s	remaining: 1m 15s
# 541:	total: 28s	remaining: 1m 15s
# 542:	total: 28.1s	remaining: 1m 15s
# 543:	total: 28.1s	remaining: 1m 15s
# 544:	total: 28.2s	remaining: 1m 15s
# 545:	total: 28.2s	remaining: 1m 15s
# 546:	total: 28.2s	remaining: 1m 15s
# 547:	total: 28.3s	remaining: 1m 14s
# 548:	total: 28.3s	remaining: 1m 14s
# 549:	total: 28.4s	remaining: 1m 14s
# 550:	total: 28.4s	remaining: 1m 14s
# 551:	total: 28.5s	remaining: 1m 14s
# 552:	total: 28.5s	remaining: 1m 14s
# 553:	total: 28.5s	remaining: 1m 14s
# 554:	total: 28.6s	remaining: 1m 14s
# 555:	total: 28.6s	remaining: 1m 14s
# 556:	total: 28.6s	remaining: 1m 14s
# 557:	total: 28.7s	remaining: 1m 14s
# 558:	total: 28.7s	remaining: 1m 14s
# 559:	total: 28.8s	remaining: 1m 14s
# 560:	total: 28.8s	remaining: 1m 13s
# 561:	total: 28.9s	remaining: 1m 13s
# 562:	total: 28.9s	remaining: 1m 13s
# 563:	total: 28.9s	remaining: 1m 13s
# 564:	total: 29s	remaining: 1m 13s
# 565:	total: 29s	remaining: 1m 13s
# 566:	total: 29.1s	remaining: 1m 13s
# 567:	total: 29.1s	remaining: 1m 13s
# 568:	total: 29.1s	remaining: 1m 13s
# 569:	total: 29.2s	remaining: 1m 13s
# 570:	total: 29.2s	remaining: 1m 13s
# 571:	total: 29.3s	remaining: 1m 13s
# 572:	total: 29.3s	remaining: 1m 12s
# 573:	total: 29.4s	remaining: 1m 12s
# 574:	total: 29.4s	remaining: 1m 12s
# 575:	total: 29.5s	remaining: 1m 12s
# 576:	total: 29.5s	remaining: 1m 12s
# 577:	total: 29.6s	remaining: 1m 12s
# 578:	total: 29.7s	remaining: 1m 12s
# 579:	total: 29.8s	remaining: 1m 12s
# 580:	total: 29.9s	remaining: 1m 13s
# 581:	total: 30s	remaining: 1m 13s
# 582:	total: 30.1s	remaining: 1m 13s
# 583:	total: 30.1s	remaining: 1m 13s
# 584:	total: 30.2s	remaining: 1m 13s
# 585:	total: 30.3s	remaining: 1m 13s
# 586:	total: 30.4s	remaining: 1m 13s
# 587:	total: 30.4s	remaining: 1m 13s
# 588:	total: 30.5s	remaining: 1m 13s
# 589:	total: 30.6s	remaining: 1m 13s
# 590:	total: 30.7s	remaining: 1m 13s
# 591:	total: 30.8s	remaining: 1m 13s
# 592:	total: 30.9s	remaining: 1m 13s
# 593:	total: 31s	remaining: 1m 13s
# 594:	total: 31.1s	remaining: 1m 13s
# 595:	total: 31.2s	remaining: 1m 13s
# 596:	total: 31.2s	remaining: 1m 13s
# 597:	total: 31.3s	remaining: 1m 13s
# 598:	total: 31.4s	remaining: 1m 13s
# 599:	total: 31.5s	remaining: 1m 13s
# 600:	total: 31.6s	remaining: 1m 13s
# 601:	total: 31.7s	remaining: 1m 13s
# 602:	total: 31.8s	remaining: 1m 13s
# 603:	total: 31.9s	remaining: 1m 13s
# 604:	total: 31.9s	remaining: 1m 13s
# 605:	total: 32s	remaining: 1m 13s
# 606:	total: 32.1s	remaining: 1m 13s
# 607:	total: 32.2s	remaining: 1m 13s
# 608:	total: 32.3s	remaining: 1m 13s
# 609:	total: 32.4s	remaining: 1m 13s
# 610:	total: 32.5s	remaining: 1m 13s
# 611:	total: 32.6s	remaining: 1m 13s
# 612:	total: 32.7s	remaining: 1m 13s
# 613:	total: 32.8s	remaining: 1m 14s
# 614:	total: 32.9s	remaining: 1m 14s
# 615:	total: 33s	remaining: 1m 14s
# 616:	total: 33.1s	remaining: 1m 14s
# 617:	total: 33.2s	remaining: 1m 14s
# 618:	total: 33.2s	remaining: 1m 14s
# 619:	total: 33.2s	remaining: 1m 14s
# 620:	total: 33.3s	remaining: 1m 13s
# 621:	total: 33.3s	remaining: 1m 13s
# 622:	total: 33.4s	remaining: 1m 13s
# 623:	total: 33.4s	remaining: 1m 13s
# 624:	total: 33.4s	remaining: 1m 13s
# 625:	total: 33.5s	remaining: 1m 13s
# 626:	total: 33.5s	remaining: 1m 13s
# 627:	total: 33.6s	remaining: 1m 13s
# 628:	total: 33.6s	remaining: 1m 13s
# 629:	total: 33.7s	remaining: 1m 13s
# 630:	total: 33.7s	remaining: 1m 13s
# 631:	total: 33.8s	remaining: 1m 13s
# 632:	total: 33.8s	remaining: 1m 12s
# 633:	total: 33.8s	remaining: 1m 12s
# 634:	total: 33.9s	remaining: 1m 12s
# 635:	total: 33.9s	remaining: 1m 12s
# 636:	total: 34s	remaining: 1m 12s
# 637:	total: 34s	remaining: 1m 12s
# 638:	total: 34s	remaining: 1m 12s
# 639:	total: 34.1s	remaining: 1m 12s
# 640:	total: 34.1s	remaining: 1m 12s
# 641:	total: 34.2s	remaining: 1m 12s
# 642:	total: 34.2s	remaining: 1m 12s
# 643:	total: 34.2s	remaining: 1m 12s
# 644:	total: 34.3s	remaining: 1m 12s
# 645:	total: 34.3s	remaining: 1m 11s
# 646:	total: 34.3s	remaining: 1m 11s
# 647:	total: 34.4s	remaining: 1m 11s
# 648:	total: 34.4s	remaining: 1m 11s
# 649:	total: 34.5s	remaining: 1m 11s
# 650:	total: 34.5s	remaining: 1m 11s
# 651:	total: 34.6s	remaining: 1m 11s
# 652:	total: 34.6s	remaining: 1m 11s
# 653:	total: 34.7s	remaining: 1m 11s
# 654:	total: 34.7s	remaining: 1m 11s
# 655:	total: 34.7s	remaining: 1m 11s
# 656:	total: 34.8s	remaining: 1m 11s
# 657:	total: 34.8s	remaining: 1m 11s
# 658:	total: 34.9s	remaining: 1m 10s
# 659:	total: 34.9s	remaining: 1m 10s
# 660:	total: 34.9s	remaining: 1m 10s
# 661:	total: 35s	remaining: 1m 10s
# 662:	total: 35s	remaining: 1m 10s
# 663:	total: 35.1s	remaining: 1m 10s
# 664:	total: 35.1s	remaining: 1m 10s
# 665:	total: 35.1s	remaining: 1m 10s
# 666:	total: 35.2s	remaining: 1m 10s
# 667:	total: 35.2s	remaining: 1m 10s
# 668:	total: 35.3s	remaining: 1m 10s
# 669:	total: 35.3s	remaining: 1m 10s
# 670:	total: 35.3s	remaining: 1m 9s
# 671:	total: 35.4s	remaining: 1m 9s
# 672:	total: 35.4s	remaining: 1m 9s
# 673:	total: 35.4s	remaining: 1m 9s
# 674:	total: 35.5s	remaining: 1m 9s
# 675:	total: 35.5s	remaining: 1m 9s
# 676:	total: 35.6s	remaining: 1m 9s
# 677:	total: 35.6s	remaining: 1m 9s
# 678:	total: 35.7s	remaining: 1m 9s
# 679:	total: 35.7s	remaining: 1m 9s
# 680:	total: 35.7s	remaining: 1m 9s
# 681:	total: 35.8s	remaining: 1m 9s
# 682:	total: 35.8s	remaining: 1m 9s
# 683:	total: 35.9s	remaining: 1m 9s
# 684:	total: 35.9s	remaining: 1m 8s
# 685:	total: 36s	remaining: 1m 8s
# 686:	total: 36s	remaining: 1m 8s
# 687:	total: 36s	remaining: 1m 8s
# 688:	total: 36.1s	remaining: 1m 8s
# 689:	total: 36.1s	remaining: 1m 8s
# 690:	total: 36.1s	remaining: 1m 8s
# 691:	total: 36.2s	remaining: 1m 8s
# 692:	total: 36.2s	remaining: 1m 8s
# 693:	total: 36.3s	remaining: 1m 8s
# 694:	total: 36.3s	remaining: 1m 8s
# 695:	total: 36.3s	remaining: 1m 8s
# 696:	total: 36.4s	remaining: 1m 7s
# 697:	total: 36.4s	remaining: 1m 7s
# 698:	total: 36.5s	remaining: 1m 7s
# 699:	total: 36.5s	remaining: 1m 7s
# 700:	total: 36.5s	remaining: 1m 7s
# 701:	total: 36.6s	remaining: 1m 7s
# 702:	total: 36.6s	remaining: 1m 7s
# 703:	total: 36.7s	remaining: 1m 7s
# 704:	total: 36.7s	remaining: 1m 7s
# 705:	total: 36.8s	remaining: 1m 7s
# 706:	total: 36.8s	remaining: 1m 7s
# 707:	total: 36.8s	remaining: 1m 7s
# 708:	total: 36.9s	remaining: 1m 7s
# 709:	total: 36.9s	remaining: 1m 7s
# 710:	total: 37s	remaining: 1m 7s
# 711:	total: 37s	remaining: 1m 6s
# 712:	total: 37s	remaining: 1m 6s
# 713:	total: 37.1s	remaining: 1m 6s
# 714:	total: 37.1s	remaining: 1m 6s
# 715:	total: 37.2s	remaining: 1m 6s
# 716:	total: 37.2s	remaining: 1m 6s
# 717:	total: 37.2s	remaining: 1m 6s
# 718:	total: 37.3s	remaining: 1m 6s
# 719:	total: 37.3s	remaining: 1m 6s
# 720:	total: 37.4s	remaining: 1m 6s
# 721:	total: 37.4s	remaining: 1m 6s
# 722:	total: 37.4s	remaining: 1m 6s
# 723:	total: 37.5s	remaining: 1m 6s
# 724:	total: 37.5s	remaining: 1m 5s
# 725:	total: 37.6s	remaining: 1m 5s
# 726:	total: 37.6s	remaining: 1m 5s
# 727:	total: 37.7s	remaining: 1m 5s
# 728:	total: 37.7s	remaining: 1m 5s
# 729:	total: 37.7s	remaining: 1m 5s
# 730:	total: 37.8s	remaining: 1m 5s
# 731:	total: 37.8s	remaining: 1m 5s
# 732:	total: 37.9s	remaining: 1m 5s
# 733:	total: 37.9s	remaining: 1m 5s
# 734:	total: 37.9s	remaining: 1m 5s
# 735:	total: 38s	remaining: 1m 5s
# 736:	total: 38s	remaining: 1m 5s
# 737:	total: 38.1s	remaining: 1m 5s
# 738:	total: 38.1s	remaining: 1m 5s
# 739:	total: 38.1s	remaining: 1m 4s
# 740:	total: 38.2s	remaining: 1m 4s
# 741:	total: 38.2s	remaining: 1m 4s
# 742:	total: 38.3s	remaining: 1m 4s
# 743:	total: 38.3s	remaining: 1m 4s
# 744:	total: 38.3s	remaining: 1m 4s
# 745:	total: 38.4s	remaining: 1m 4s
# 746:	total: 38.4s	remaining: 1m 4s
# 747:	total: 38.4s	remaining: 1m 4s
# 748:	total: 38.5s	remaining: 1m 4s
# 749:	total: 38.5s	remaining: 1m 4s
# 750:	total: 38.6s	remaining: 1m 4s
# 751:	total: 38.6s	remaining: 1m 4s
# 752:	total: 38.7s	remaining: 1m 4s
# 753:	total: 38.7s	remaining: 1m 3s
# 754:	total: 38.8s	remaining: 1m 3s
# 755:	total: 38.8s	remaining: 1m 3s
# 756:	total: 38.8s	remaining: 1m 3s
# 757:	total: 38.9s	remaining: 1m 3s
# 758:	total: 38.9s	remaining: 1m 3s
# 759:	total: 39s	remaining: 1m 3s
# 760:	total: 39s	remaining: 1m 3s
# 761:	total: 39s	remaining: 1m 3s
# 762:	total: 39.1s	remaining: 1m 3s
# 763:	total: 39.1s	remaining: 1m 3s
# 764:	total: 39.2s	remaining: 1m 3s
# 765:	total: 39.2s	remaining: 1m 3s
# 766:	total: 39.2s	remaining: 1m 3s
# 767:	total: 39.3s	remaining: 1m 2s
# 768:	total: 39.3s	remaining: 1m 2s
# 769:	total: 39.4s	remaining: 1m 2s
# 770:	total: 39.4s	remaining: 1m 2s
# 771:	total: 39.4s	remaining: 1m 2s
# 772:	total: 39.5s	remaining: 1m 2s
# 773:	total: 39.5s	remaining: 1m 2s
# 774:	total: 39.6s	remaining: 1m 2s
# 775:	total: 39.6s	remaining: 1m 2s
# 776:	total: 39.7s	remaining: 1m 2s
# 777:	total: 39.7s	remaining: 1m 2s
# 778:	total: 39.8s	remaining: 1m 2s
# 779:	total: 39.8s	remaining: 1m 2s
# 780:	total: 39.8s	remaining: 1m 2s
# 781:	total: 39.9s	remaining: 1m 2s
# 782:	total: 39.9s	remaining: 1m 2s
# 783:	total: 40s	remaining: 1m 1s
# 784:	total: 40s	remaining: 1m 1s
# 785:	total: 40s	remaining: 1m 1s
# 786:	total: 40.1s	remaining: 1m 1s
# 787:	total: 40.1s	remaining: 1m 1s
# 788:	total: 40.2s	remaining: 1m 1s
# 789:	total: 40.2s	remaining: 1m 1s
# 790:	total: 40.2s	remaining: 1m 1s
# 791:	total: 40.3s	remaining: 1m 1s
# 792:	total: 40.3s	remaining: 1m 1s
# 793:	total: 40.4s	remaining: 1m 1s
# 794:	total: 40.4s	remaining: 1m 1s
# 795:	total: 40.5s	remaining: 1m 1s
# 796:	total: 40.5s	remaining: 1m 1s
# 797:	total: 40.5s	remaining: 1m 1s
# 798:	total: 40.6s	remaining: 1m 1s
# 799:	total: 40.7s	remaining: 1m 1s
# 800:	total: 40.7s	remaining: 1m
# 801:	total: 40.8s	remaining: 1m
# 802:	total: 40.8s	remaining: 1m
# 803:	total: 40.8s	remaining: 1m
# 804:	total: 40.9s	remaining: 1m
# 805:	total: 40.9s	remaining: 1m
# 806:	total: 41s	remaining: 1m
# 807:	total: 41s	remaining: 1m
# 808:	total: 41s	remaining: 1m
# 809:	total: 41.1s	remaining: 1m
# 810:	total: 41.1s	remaining: 1m
# 811:	total: 41.2s	remaining: 1m
# 812:	total: 41.2s	remaining: 1m
# 813:	total: 41.3s	remaining: 1m
# 814:	total: 41.3s	remaining: 1m
# 815:	total: 41.3s	remaining: 60s
# 816:	total: 41.4s	remaining: 59.9s
# 817:	total: 41.4s	remaining: 59.8s
# 818:	total: 41.5s	remaining: 59.8s
# 819:	total: 41.5s	remaining: 59.7s
# 820:	total: 41.5s	remaining: 59.7s
# 821:	total: 41.6s	remaining: 59.6s
# 822:	total: 41.6s	remaining: 59.5s
# 823:	total: 41.7s	remaining: 59.5s
# 824:	total: 41.7s	remaining: 59.4s
# 825:	total: 41.8s	remaining: 59.4s
# 826:	total: 41.8s	remaining: 59.3s
# 827:	total: 41.9s	remaining: 59.2s
# 828:	total: 41.9s	remaining: 59.2s
# 829:	total: 41.9s	remaining: 59.1s
# 830:	total: 42s	remaining: 59s
# 831:	total: 42s	remaining: 59s
# 832:	total: 42s	remaining: 58.9s
# 833:	total: 42.1s	remaining: 58.8s
# 834:	total: 42.1s	remaining: 58.8s
# 835:	total: 42.2s	remaining: 58.7s
# 836:	total: 42.2s	remaining: 58.6s
# 837:	total: 42.2s	remaining: 58.6s
# 838:	total: 42.3s	remaining: 58.5s
# 839:	total: 42.3s	remaining: 58.4s
# 840:	total: 42.4s	remaining: 58.4s
# 841:	total: 42.4s	remaining: 58.3s
# 842:	total: 42.4s	remaining: 58.2s
# 843:	total: 42.5s	remaining: 58.2s
# 844:	total: 42.5s	remaining: 58.1s
# 845:	total: 42.5s	remaining: 58s
# 846:	total: 42.6s	remaining: 58s
# 847:	total: 42.6s	remaining: 57.9s
# 848:	total: 42.7s	remaining: 57.8s
# 849:	total: 42.7s	remaining: 57.8s
# 850:	total: 42.8s	remaining: 57.7s
# 851:	total: 42.8s	remaining: 57.7s
# 852:	total: 42.9s	remaining: 57.6s
# 853:	total: 42.9s	remaining: 57.6s
# 854:	total: 42.9s	remaining: 57.5s
# 855:	total: 43s	remaining: 57.4s
# 856:	total: 43s	remaining: 57.4s
# 857:	total: 43s	remaining: 57.3s
# 858:	total: 43.1s	remaining: 57.2s
# 859:	total: 43.1s	remaining: 57.2s
# 860:	total: 43.2s	remaining: 57.2s
# 861:	total: 43.3s	remaining: 57.1s
# 862:	total: 43.4s	remaining: 57.2s
# 863:	total: 43.5s	remaining: 57.1s
# 864:	total: 43.6s	remaining: 57.2s
# 865:	total: 43.7s	remaining: 57.2s
# 866:	total: 43.8s	remaining: 57.2s
# 867:	total: 43.9s	remaining: 57.2s
# 868:	total: 44s	remaining: 57.2s
# 869:	total: 44s	remaining: 57.2s
# 870:	total: 44.1s	remaining: 57.2s
# 871:	total: 44.2s	remaining: 57.2s
# 872:	total: 44.3s	remaining: 57.2s
# 873:	total: 44.4s	remaining: 57.2s
# 874:	total: 44.5s	remaining: 57.2s
# 875:	total: 44.6s	remaining: 57.3s
# 876:	total: 44.7s	remaining: 57.2s
# 877:	total: 44.8s	remaining: 57.2s
# 878:	total: 44.9s	remaining: 57.2s
# 879:	total: 44.9s	remaining: 57.2s
# 880:	total: 45s	remaining: 57.2s
# 881:	total: 45.1s	remaining: 57.2s
# 882:	total: 45.2s	remaining: 57.1s
# 883:	total: 45.3s	remaining: 57.1s
# 884:	total: 45.4s	remaining: 57.1s
# 885:	total: 45.4s	remaining: 57.1s
# 886:	total: 45.5s	remaining: 57.1s
# 887:	total: 45.6s	remaining: 57.1s
# 888:	total: 45.7s	remaining: 57.1s
# 889:	total: 45.8s	remaining: 57.1s
# 890:	total: 45.9s	remaining: 57.1s
# 891:	total: 46s	remaining: 57.1s
# 892:	total: 46.1s	remaining: 57.1s
# 893:	total: 46.1s	remaining: 57.1s
# 894:	total: 46.2s	remaining: 57.1s
# 895:	total: 46.3s	remaining: 57.1s
# 896:	total: 46.4s	remaining: 57.1s
# 897:	total: 46.5s	remaining: 57.1s
# 898:	total: 46.6s	remaining: 57.1s
# 899:	total: 46.7s	remaining: 57.1s
# 900:	total: 46.8s	remaining: 57.1s
# 901:	total: 46.9s	remaining: 57.1s
# 902:	total: 47s	remaining: 57.1s
# 903:	total: 47.1s	remaining: 57.1s
# 904:	total: 47.2s	remaining: 57.1s
# 905:	total: 47.2s	remaining: 57s
# 906:	total: 47.2s	remaining: 56.9s
# 907:	total: 47.3s	remaining: 56.9s
# 908:	total: 47.3s	remaining: 56.8s
# 909:	total: 47.4s	remaining: 56.7s
# 910:	total: 47.4s	remaining: 56.7s
# 911:	total: 47.4s	remaining: 56.6s
# 912:	total: 47.5s	remaining: 56.5s
# 913:	total: 47.5s	remaining: 56.5s
# 914:	total: 47.6s	remaining: 56.4s
# 915:	total: 47.6s	remaining: 56.4s
# 916:	total: 47.7s	remaining: 56.3s
# 917:	total: 47.7s	remaining: 56.2s
# 918:	total: 47.7s	remaining: 56.1s
# 919:	total: 47.8s	remaining: 56.1s
# 920:	total: 47.8s	remaining: 56s
# 921:	total: 47.9s	remaining: 56s
# 922:	total: 47.9s	remaining: 55.9s
# 923:	total: 47.9s	remaining: 55.8s
# 924:	total: 48s	remaining: 55.8s
# 925:	total: 48s	remaining: 55.7s
# 926:	total: 48.1s	remaining: 55.7s
# 927:	total: 48.1s	remaining: 55.6s
# 928:	total: 48.2s	remaining: 55.5s
# 929:	total: 48.2s	remaining: 55.4s
# 930:	total: 48.2s	remaining: 55.4s
# 931:	total: 48.3s	remaining: 55.4s
# 932:	total: 48.4s	remaining: 55.4s
# 933:	total: 48.5s	remaining: 55.3s
# 934:	total: 48.5s	remaining: 55.3s
# 935:	total: 48.6s	remaining: 55.2s
# 936:	total: 48.6s	remaining: 55.1s
# 937:	total: 48.6s	remaining: 55.1s
# 938:	total: 48.7s	remaining: 55s
# 939:	total: 48.7s	remaining: 55s
# 940:	total: 48.8s	remaining: 54.9s
# 941:	total: 48.8s	remaining: 54.8s
# 942:	total: 48.9s	remaining: 54.8s
# 943:	total: 48.9s	remaining: 54.7s
# 944:	total: 48.9s	remaining: 54.6s
# 945:	total: 49s	remaining: 54.6s
# 946:	total: 49s	remaining: 54.5s
# 947:	total: 49.1s	remaining: 54.5s
# 948:	total: 49.1s	remaining: 54.4s
# 949:	total: 49.2s	remaining: 54.3s
# 950:	total: 49.2s	remaining: 54.3s
# 951:	total: 49.2s	remaining: 54.2s
# 952:	total: 49.3s	remaining: 54.1s
# 953:	total: 49.3s	remaining: 54.1s
# 954:	total: 49.4s	remaining: 54s
# 955:	total: 49.4s	remaining: 53.9s
# 956:	total: 49.4s	remaining: 53.9s
# 957:	total: 49.5s	remaining: 53.8s
# 958:	total: 49.5s	remaining: 53.8s
# 959:	total: 49.6s	remaining: 53.7s
# 960:	total: 49.6s	remaining: 53.6s
# 961:	total: 49.6s	remaining: 53.6s
# 962:	total: 49.7s	remaining: 53.5s
# 963:	total: 49.7s	remaining: 53.4s
# 964:	total: 49.8s	remaining: 53.4s
# 965:	total: 49.8s	remaining: 53.3s
# 966:	total: 49.9s	remaining: 53.3s
# 967:	total: 49.9s	remaining: 53.2s
# 968:	total: 49.9s	remaining: 53.1s
# 969:	total: 50s	remaining: 53.1s
# 970:	total: 50s	remaining: 53s
# 971:	total: 50.1s	remaining: 52.9s
# 972:	total: 50.1s	remaining: 52.9s
# 973:	total: 50.1s	remaining: 52.8s
# 974:	total: 50.2s	remaining: 52.8s
# 975:	total: 50.2s	remaining: 52.7s
# 976:	total: 50.3s	remaining: 52.6s
# 977:	total: 50.3s	remaining: 52.6s
# 978:	total: 50.3s	remaining: 52.5s
# 979:	total: 50.4s	remaining: 52.4s
# 980:	total: 50.4s	remaining: 52.4s
# 981:	total: 50.5s	remaining: 52.3s
# 982:	total: 50.5s	remaining: 52.2s
# 983:	total: 50.6s	remaining: 52.2s
# 984:	total: 50.6s	remaining: 52.1s
# 985:	total: 50.6s	remaining: 52.1s
# 986:	total: 50.7s	remaining: 52s
# 987:	total: 50.7s	remaining: 51.9s
# 988:	total: 50.8s	remaining: 51.9s
# 989:	total: 50.8s	remaining: 51.8s
# 990:	total: 50.8s	remaining: 51.8s
# 991:	total: 50.9s	remaining: 51.7s
# 992:	total: 50.9s	remaining: 51.6s
# 993:	total: 51s	remaining: 51.6s
# 994:	total: 51s	remaining: 51.5s
# 995:	total: 51s	remaining: 51.5s
# 996:	total: 51.1s	remaining: 51.4s
# 997:	total: 51.1s	remaining: 51.3s
# 998:	total: 51.2s	remaining: 51.3s
# 999:	total: 51.2s	remaining: 51.2s
# 1000:	total: 51.3s	remaining: 51.2s
# 1001:	total: 51.3s	remaining: 51.1s
# 1002:	total: 51.3s	remaining: 51s
# 1003:	total: 51.4s	remaining: 51s
# 1004:	total: 51.4s	remaining: 50.9s
# 1005:	total: 51.5s	remaining: 50.8s
# 1006:	total: 51.5s	remaining: 50.8s
# 1007:	total: 51.6s	remaining: 50.8s
# 1008:	total: 51.6s	remaining: 50.7s
# 1009:	total: 51.6s	remaining: 50.6s
# 1010:	total: 51.7s	remaining: 50.6s
# 1011:	total: 51.7s	remaining: 50.5s
# 1012:	total: 51.8s	remaining: 50.4s
# 1013:	total: 51.8s	remaining: 50.4s
# 1014:	total: 51.9s	remaining: 50.3s
# 1015:	total: 51.9s	remaining: 50.3s
# 1016:	total: 51.9s	remaining: 50.2s
# 1017:	total: 52s	remaining: 50.1s
# 1018:	total: 52s	remaining: 50.1s
# 1019:	total: 52.1s	remaining: 50s
# 1020:	total: 52.1s	remaining: 49.9s
# 1021:	total: 52.1s	remaining: 49.9s
# 1022:	total: 52.2s	remaining: 49.8s
# 1023:	total: 52.2s	remaining: 49.8s
# 1024:	total: 52.3s	remaining: 49.7s
# 1025:	total: 52.3s	remaining: 49.7s
# 1026:	total: 52.3s	remaining: 49.6s
# 1027:	total: 52.4s	remaining: 49.5s
# 1028:	total: 52.4s	remaining: 49.5s
# 1029:	total: 52.5s	remaining: 49.4s
# 1030:	total: 52.5s	remaining: 49.4s
# 1031:	total: 52.6s	remaining: 49.3s
# 1032:	total: 52.6s	remaining: 49.3s
# 1033:	total: 52.6s	remaining: 49.2s
# 1034:	total: 52.7s	remaining: 49.1s
# 1035:	total: 52.7s	remaining: 49.1s
# 1036:	total: 52.8s	remaining: 49s
# 1037:	total: 52.8s	remaining: 48.9s
# 1038:	total: 52.8s	remaining: 48.9s
# 1039:	total: 52.9s	remaining: 48.8s
# 1040:	total: 52.9s	remaining: 48.8s
# 1041:	total: 53s	remaining: 48.7s
# 1042:	total: 53s	remaining: 48.6s
# 1043:	total: 53s	remaining: 48.6s
# 1044:	total: 53.1s	remaining: 48.5s
# 1045:	total: 53.1s	remaining: 48.5s
# 1046:	total: 53.2s	remaining: 48.4s
# 1047:	total: 53.2s	remaining: 48.3s
# 1048:	total: 53.3s	remaining: 48.3s
# 1049:	total: 53.3s	remaining: 48.2s
# 1050:	total: 53.3s	remaining: 48.2s
# 1051:	total: 53.4s	remaining: 48.1s
# 1052:	total: 53.4s	remaining: 48s
# 1053:	total: 53.5s	remaining: 48s
# 1054:	total: 53.5s	remaining: 47.9s
# 1055:	total: 53.6s	remaining: 47.9s
# 1056:	total: 53.6s	remaining: 47.8s
# 1057:	total: 53.6s	remaining: 47.8s
# 1058:	total: 53.7s	remaining: 47.7s
# 1059:	total: 53.7s	remaining: 47.6s
# 1060:	total: 53.8s	remaining: 47.6s
# 1061:	total: 53.8s	remaining: 47.5s
# 1062:	total: 53.8s	remaining: 47.5s
# 1063:	total: 53.9s	remaining: 47.4s
# 1064:	total: 53.9s	remaining: 47.3s
# 1065:	total: 54s	remaining: 47.3s
# 1066:	total: 54s	remaining: 47.2s
# 1067:	total: 54s	remaining: 47.2s
# 1068:	total: 54.1s	remaining: 47.1s
# 1069:	total: 54.1s	remaining: 47s
# 1070:	total: 54.2s	remaining: 47s
# 1071:	total: 54.2s	remaining: 46.9s
# 1072:	total: 54.3s	remaining: 46.9s
# 1073:	total: 54.3s	remaining: 46.8s
# 1074:	total: 54.3s	remaining: 46.8s
# 1075:	total: 54.4s	remaining: 46.7s
# 1076:	total: 54.4s	remaining: 46.6s
# 1077:	total: 54.5s	remaining: 46.6s
# 1078:	total: 54.5s	remaining: 46.5s
# 1079:	total: 54.6s	remaining: 46.5s
# 1080:	total: 54.6s	remaining: 46.4s
# 1081:	total: 54.6s	remaining: 46.4s
# 1082:	total: 54.7s	remaining: 46.3s
# 1083:	total: 54.7s	remaining: 46.2s
# 1084:	total: 54.8s	remaining: 46.2s
# 1085:	total: 54.8s	remaining: 46.1s
# 1086:	total: 54.9s	remaining: 46.1s
# 1087:	total: 54.9s	remaining: 46s
# 1088:	total: 54.9s	remaining: 46s
# 1089:	total: 55s	remaining: 45.9s
# 1090:	total: 55s	remaining: 45.8s
# 1091:	total: 55s	remaining: 45.8s
# 1092:	total: 55.1s	remaining: 45.7s
# 1093:	total: 55.1s	remaining: 45.7s
# 1094:	total: 55.2s	remaining: 45.6s
# 1095:	total: 55.2s	remaining: 45.6s
# 1096:	total: 55.3s	remaining: 45.5s
# 1097:	total: 55.3s	remaining: 45.4s
# 1098:	total: 55.3s	remaining: 45.4s
# 1099:	total: 55.4s	remaining: 45.3s
# 1100:	total: 55.4s	remaining: 45.3s
# 1101:	total: 55.5s	remaining: 45.2s
# 1102:	total: 55.5s	remaining: 45.1s
# 1103:	total: 55.6s	remaining: 45.1s
# 1104:	total: 55.6s	remaining: 45s
# 1105:	total: 55.6s	remaining: 45s
# 1106:	total: 55.7s	remaining: 44.9s
# 1107:	total: 55.7s	remaining: 44.8s
# 1108:	total: 55.8s	remaining: 44.8s
# 1109:	total: 55.8s	remaining: 44.7s
# 1110:	total: 55.8s	remaining: 44.7s
# 1111:	total: 55.9s	remaining: 44.6s
# 1112:	total: 55.9s	remaining: 44.6s
# 1113:	total: 55.9s	remaining: 44.5s
# 1114:	total: 56s	remaining: 44.4s
# 1115:	total: 56s	remaining: 44.4s
# 1116:	total: 56.1s	remaining: 44.3s
# 1117:	total: 56.1s	remaining: 44.3s
# 1118:	total: 56.1s	remaining: 44.2s
# 1119:	total: 56.2s	remaining: 44.1s
# 1120:	total: 56.2s	remaining: 44.1s
# 1121:	total: 56.3s	remaining: 44s
# 1122:	total: 56.3s	remaining: 44s
# 1123:	total: 56.3s	remaining: 43.9s
# 1124:	total: 56.4s	remaining: 43.9s
# 1125:	total: 56.4s	remaining: 43.8s
# 1126:	total: 56.5s	remaining: 43.7s
# 1127:	total: 56.5s	remaining: 43.7s
# 1128:	total: 56.6s	remaining: 43.6s
# 1129:	total: 56.6s	remaining: 43.6s
# 1130:	total: 56.6s	remaining: 43.5s
# 1131:	total: 56.7s	remaining: 43.5s
# 1132:	total: 56.7s	remaining: 43.4s
# 1133:	total: 56.8s	remaining: 43.3s
# 1134:	total: 56.8s	remaining: 43.3s
# 1135:	total: 56.8s	remaining: 43.2s
# 1136:	total: 56.9s	remaining: 43.2s
# 1137:	total: 56.9s	remaining: 43.1s
# 1138:	total: 57s	remaining: 43.1s
# 1139:	total: 57s	remaining: 43s
# 1140:	total: 57s	remaining: 42.9s
# 1141:	total: 57.1s	remaining: 42.9s
# 1142:	total: 57.1s	remaining: 42.8s
# 1143:	total: 57.2s	remaining: 42.8s
# 1144:	total: 57.3s	remaining: 42.8s
# 1145:	total: 57.3s	remaining: 42.7s
# 1146:	total: 57.4s	remaining: 42.7s
# 1147:	total: 57.5s	remaining: 42.7s
# 1148:	total: 57.6s	remaining: 42.7s
# 1149:	total: 57.7s	remaining: 42.6s
# 1150:	total: 57.7s	remaining: 42.6s
# 1151:	total: 57.8s	remaining: 42.6s
# 1152:	total: 57.9s	remaining: 42.6s
# 1153:	total: 58s	remaining: 42.5s
# 1154:	total: 58.1s	remaining: 42.5s
# 1155:	total: 58.2s	remaining: 42.5s
# 1156:	total: 58.3s	remaining: 42.5s
# 1157:	total: 58.4s	remaining: 42.5s
# 1158:	total: 58.5s	remaining: 42.5s
# 1159:	total: 58.6s	remaining: 42.5s
# 1160:	total: 58.7s	remaining: 42.4s
# 1161:	total: 58.8s	remaining: 42.4s
# 1162:	total: 58.9s	remaining: 42.4s
# 1163:	total: 59s	remaining: 42.4s
# 1164:	total: 59.1s	remaining: 42.3s
# 1165:	total: 59.2s	remaining: 42.3s
# 1166:	total: 59.2s	remaining: 42.3s
# 1167:	total: 59.3s	remaining: 42.3s
# 1168:	total: 59.4s	remaining: 42.2s
# 1169:	total: 59.5s	remaining: 42.2s
# 1170:	total: 59.6s	remaining: 42.2s
# 1171:	total: 59.6s	remaining: 42.1s
# 1172:	total: 59.7s	remaining: 42.1s
# 1173:	total: 59.8s	remaining: 42.1s
# 1174:	total: 59.9s	remaining: 42.1s
# 1175:	total: 1m	remaining: 42s
# 1176:	total: 1m	remaining: 42s
# 1177:	total: 1m	remaining: 42s
# 1178:	total: 1m	remaining: 42s
# 1179:	total: 1m	remaining: 41.9s
# 1180:	total: 1m	remaining: 41.9s
# 1181:	total: 1m	remaining: 41.9s
# 1182:	total: 1m	remaining: 41.8s
# 1183:	total: 1m	remaining: 41.8s
# 1184:	total: 1m	remaining: 41.7s
# 1185:	total: 1m	remaining: 41.6s
# 1186:	total: 1m	remaining: 41.6s
# 1187:	total: 1m	remaining: 41.5s
# 1188:	total: 1m	remaining: 41.5s
# 1189:	total: 1m	remaining: 41.4s
# 1190:	total: 1m	remaining: 41.4s
# 1191:	total: 1m	remaining: 41.3s
# 1192:	total: 1m	remaining: 41.2s
# 1193:	total: 1m 1s	remaining: 41.2s
# 1194:	total: 1m 1s	remaining: 41.1s
# 1195:	total: 1m 1s	remaining: 41.1s
# 1196:	total: 1m 1s	remaining: 41s
# 1197:	total: 1m 1s	remaining: 40.9s
# 1198:	total: 1m 1s	remaining: 40.9s
# 1199:	total: 1m 1s	remaining: 40.8s
# 1200:	total: 1m 1s	remaining: 40.8s
# 1201:	total: 1m 1s	remaining: 40.7s
# 1202:	total: 1m 1s	remaining: 40.7s
# 1203:	total: 1m 1s	remaining: 40.6s
# 1204:	total: 1m 1s	remaining: 40.6s
# 1205:	total: 1m 1s	remaining: 40.5s
# 1206:	total: 1m 1s	remaining: 40.4s
# 1207:	total: 1m 1s	remaining: 40.4s
# 1208:	total: 1m 1s	remaining: 40.3s
# 1209:	total: 1m 1s	remaining: 40.3s
# 1210:	total: 1m 1s	remaining: 40.2s
# 1211:	total: 1m 1s	remaining: 40.2s
# 1212:	total: 1m 1s	remaining: 40.1s
# 1213:	total: 1m 1s	remaining: 40s
# 1214:	total: 1m 1s	remaining: 40s
# 1215:	total: 1m 1s	remaining: 39.9s
# 1216:	total: 1m 1s	remaining: 39.9s
# 1217:	total: 1m 1s	remaining: 39.8s
# 1218:	total: 1m 2s	remaining: 39.7s
# 1219:	total: 1m 2s	remaining: 39.7s
# 1220:	total: 1m 2s	remaining: 39.6s
# 1221:	total: 1m 2s	remaining: 39.6s
# 1222:	total: 1m 2s	remaining: 39.5s
# 1223:	total: 1m 2s	remaining: 39.5s
# 1224:	total: 1m 2s	remaining: 39.4s
# 1225:	total: 1m 2s	remaining: 39.3s
# 1226:	total: 1m 2s	remaining: 39.3s
# 1227:	total: 1m 2s	remaining: 39.2s
# 1228:	total: 1m 2s	remaining: 39.2s
# 1229:	total: 1m 2s	remaining: 39.1s
# 1230:	total: 1m 2s	remaining: 39.1s
# 1231:	total: 1m 2s	remaining: 39s
# 1232:	total: 1m 2s	remaining: 39s
# 1233:	total: 1m 2s	remaining: 38.9s
# 1234:	total: 1m 2s	remaining: 38.8s
# 1235:	total: 1m 2s	remaining: 38.8s
# 1236:	total: 1m 2s	remaining: 38.7s
# 1237:	total: 1m 2s	remaining: 38.7s
# 1238:	total: 1m 2s	remaining: 38.6s
# 1239:	total: 1m 2s	remaining: 38.5s
# 1240:	total: 1m 2s	remaining: 38.5s
# 1241:	total: 1m 2s	remaining: 38.4s
# 1242:	total: 1m 3s	remaining: 38.4s
# 1243:	total: 1m 3s	remaining: 38.3s
# 1244:	total: 1m 3s	remaining: 38.3s
# 1245:	total: 1m 3s	remaining: 38.2s
# 1246:	total: 1m 3s	remaining: 38.1s
# 1247:	total: 1m 3s	remaining: 38.1s
# 1248:	total: 1m 3s	remaining: 38s
# 1249:	total: 1m 3s	remaining: 38s
# 1250:	total: 1m 3s	remaining: 37.9s
# 1251:	total: 1m 3s	remaining: 37.9s
# 1252:	total: 1m 3s	remaining: 37.8s
# 1253:	total: 1m 3s	remaining: 37.8s
# 1254:	total: 1m 3s	remaining: 37.7s
# 1255:	total: 1m 3s	remaining: 37.7s
# 1256:	total: 1m 3s	remaining: 37.6s
# 1257:	total: 1m 3s	remaining: 37.5s
# 1258:	total: 1m 3s	remaining: 37.5s
# 1259:	total: 1m 3s	remaining: 37.4s
# 1260:	total: 1m 3s	remaining: 37.4s
# 1261:	total: 1m 3s	remaining: 37.3s
# 1262:	total: 1m 3s	remaining: 37.3s
# 1263:	total: 1m 3s	remaining: 37.2s
# 1264:	total: 1m 3s	remaining: 37.2s
# 1265:	total: 1m 3s	remaining: 37.1s
# 1266:	total: 1m 4s	remaining: 37s
# 1267:	total: 1m 4s	remaining: 37s
# 1268:	total: 1m 4s	remaining: 36.9s
# 1269:	total: 1m 4s	remaining: 36.9s
# 1270:	total: 1m 4s	remaining: 36.8s
# 1271:	total: 1m 4s	remaining: 36.8s
# 1272:	total: 1m 4s	remaining: 36.7s
# 1273:	total: 1m 4s	remaining: 36.6s
# 1274:	total: 1m 4s	remaining: 36.6s
# 1275:	total: 1m 4s	remaining: 36.5s
# 1276:	total: 1m 4s	remaining: 36.5s
# 1277:	total: 1m 4s	remaining: 36.4s
# 1278:	total: 1m 4s	remaining: 36.4s
# 1279:	total: 1m 4s	remaining: 36.3s
# 1280:	total: 1m 4s	remaining: 36.3s
# 1281:	total: 1m 4s	remaining: 36.2s
# 1282:	total: 1m 4s	remaining: 36.2s
# 1283:	total: 1m 4s	remaining: 36.1s
# 1284:	total: 1m 4s	remaining: 36s
# 1285:	total: 1m 4s	remaining: 36s
# 1286:	total: 1m 4s	remaining: 35.9s
# 1287:	total: 1m 4s	remaining: 35.9s
# 1288:	total: 1m 4s	remaining: 35.8s
# 1289:	total: 1m 4s	remaining: 35.8s
# 1290:	total: 1m 5s	remaining: 35.7s
# 1291:	total: 1m 5s	remaining: 35.7s
# 1292:	total: 1m 5s	remaining: 35.6s
# 1293:	total: 1m 5s	remaining: 35.5s
# 1294:	total: 1m 5s	remaining: 35.5s
# 1295:	total: 1m 5s	remaining: 35.4s
# 1296:	total: 1m 5s	remaining: 35.4s
# 1297:	total: 1m 5s	remaining: 35.3s
# 1298:	total: 1m 5s	remaining: 35.3s
# 1299:	total: 1m 5s	remaining: 35.2s
# 1300:	total: 1m 5s	remaining: 35.2s
# 1301:	total: 1m 5s	remaining: 35.1s
# 1302:	total: 1m 5s	remaining: 35s
# 1303:	total: 1m 5s	remaining: 35s
# 1304:	total: 1m 5s	remaining: 34.9s
# 1305:	total: 1m 5s	remaining: 34.9s
# 1306:	total: 1m 5s	remaining: 34.8s
# 1307:	total: 1m 5s	remaining: 34.8s
# 1308:	total: 1m 5s	remaining: 34.7s
# 1309:	total: 1m 5s	remaining: 34.7s
# 1310:	total: 1m 5s	remaining: 34.6s
# 1311:	total: 1m 5s	remaining: 34.5s
# 1312:	total: 1m 5s	remaining: 34.5s
# 1313:	total: 1m 5s	remaining: 34.4s
# 1314:	total: 1m 6s	remaining: 34.4s
# 1315:	total: 1m 6s	remaining: 34.3s
# 1316:	total: 1m 6s	remaining: 34.3s
# 1317:	total: 1m 6s	remaining: 34.2s
# 1318:	total: 1m 6s	remaining: 34.2s
# 1319:	total: 1m 6s	remaining: 34.1s
# 1320:	total: 1m 6s	remaining: 34s
# 1321:	total: 1m 6s	remaining: 34s
# 1322:	total: 1m 6s	remaining: 33.9s
# 1323:	total: 1m 6s	remaining: 33.9s
# 1324:	total: 1m 6s	remaining: 33.8s
# 1325:	total: 1m 6s	remaining: 33.8s
# 1326:	total: 1m 6s	remaining: 33.7s
# 1327:	total: 1m 6s	remaining: 33.7s
# 1328:	total: 1m 6s	remaining: 33.6s
# 1329:	total: 1m 6s	remaining: 33.6s
# 1330:	total: 1m 6s	remaining: 33.5s
# 1331:	total: 1m 6s	remaining: 33.5s
# 1332:	total: 1m 6s	remaining: 33.4s
# 1333:	total: 1m 6s	remaining: 33.3s
# 1334:	total: 1m 6s	remaining: 33.3s
# 1335:	total: 1m 6s	remaining: 33.2s
# 1336:	total: 1m 6s	remaining: 33.2s
# 1337:	total: 1m 6s	remaining: 33.1s
# 1338:	total: 1m 6s	remaining: 33.1s
# 1339:	total: 1m 7s	remaining: 33s
# 1340:	total: 1m 7s	remaining: 33s
# 1341:	total: 1m 7s	remaining: 32.9s
# 1342:	total: 1m 7s	remaining: 32.8s
# 1343:	total: 1m 7s	remaining: 32.8s
# 1344:	total: 1m 7s	remaining: 32.7s
# 1345:	total: 1m 7s	remaining: 32.7s
# 1346:	total: 1m 7s	remaining: 32.6s
# 1347:	total: 1m 7s	remaining: 32.6s
# 1348:	total: 1m 7s	remaining: 32.5s
# 1349:	total: 1m 7s	remaining: 32.5s
# 1350:	total: 1m 7s	remaining: 32.4s
# 1351:	total: 1m 7s	remaining: 32.4s
# 1352:	total: 1m 7s	remaining: 32.3s
# 1353:	total: 1m 7s	remaining: 32.3s
# 1354:	total: 1m 7s	remaining: 32.2s
# 1355:	total: 1m 7s	remaining: 32.1s
# 1356:	total: 1m 7s	remaining: 32.1s
# ...
# 1567:	total: 1m 18s	remaining: 21.6s
# 1568:	total: 1m 18s	remaining: 21.6s
# 1569:	total: 1m 18s	remaining: 21.5s
# 1570:	total: 1m 18s	remaining: 21.5s
# 1571:	total: 1m 18s	remaining: 21.4s
# 1572:	total: 1m 18s	remaining: 21.4s
# 1573:	total: 1m 18s	remaining: 21.3s
# 1574:	total: 1m 18s	remaining: 21.3s
# 1575:	total: 1m 18s	remaining: 21.2s
# 1576:	total: 1m 18s	remaining: 21.2s
# 1577:	total: 1m 18s	remaining: 21.1s
# 1578:	total: 1m 19s	remaining: 21.1s
# 1579:	total: 1m 19s	remaining: 21s
# 1580:	total: 1m 19s	remaining: 21s
# 1581:	total: 1m 19s	remaining: 20.9s
# 1582:	total: 1m 19s	remaining: 20.9s
# 1583:	total: 1m 19s	remaining: 20.8s
# 1584:	total: 1m 19s	remaining: 20.8s
# 1585:	total: 1m 19s	remaining: 20.7s
# 1586:	total: 1m 19s	remaining: 20.6s
# 1587:	total: 1m 19s	remaining: 20.6s
# 1588:	total: 1m 19s	remaining: 20.5s
# 1589:	total: 1m 19s	remaining: 20.5s
# 1590:	total: 1m 19s	remaining: 20.4s
# 1591:	total: 1m 19s	remaining: 20.4s
# 1592:	total: 1m 19s	remaining: 20.3s
# 1593:	total: 1m 19s	remaining: 20.3s
# 1594:	total: 1m 19s	remaining: 20.2s
# 1595:	total: 1m 19s	remaining: 20.2s
# 1596:	total: 1m 19s	remaining: 20.1s
# 1597:	total: 1m 19s	remaining: 20.1s
# 1598:	total: 1m 19s	remaining: 20s
# 1599:	total: 1m 19s	remaining: 20s
# 1600:	total: 1m 19s	remaining: 19.9s
# 1601:	total: 1m 19s	remaining: 19.9s
# 1602:	total: 1m 20s	remaining: 19.8s
# 1603:	total: 1m 20s	remaining: 19.8s
# 1604:	total: 1m 20s	remaining: 19.7s
# 1605:	total: 1m 20s	remaining: 19.7s
# 1606:	total: 1m 20s	remaining: 19.6s
# 1607:	total: 1m 20s	remaining: 19.6s
# 1608:	total: 1m 20s	remaining: 19.5s
# 1609:	total: 1m 20s	remaining: 19.4s
# 1610:	total: 1m 20s	remaining: 19.4s
# 1611:	total: 1m 20s	remaining: 19.3s
# 1612:	total: 1m 20s	remaining: 19.3s
# 1613:	total: 1m 20s	remaining: 19.2s
# 1614:	total: 1m 20s	remaining: 19.2s
# 1615:	total: 1m 20s	remaining: 19.1s
# 1616:	total: 1m 20s	remaining: 19.1s
# 1617:	total: 1m 20s	remaining: 19s
# 1618:	total: 1m 20s	remaining: 19s
# 1619:	total: 1m 20s	remaining: 18.9s
# 1620:	total: 1m 20s	remaining: 18.9s
# 1621:	total: 1m 20s	remaining: 18.8s
# 1622:	total: 1m 20s	remaining: 18.8s
# 1623:	total: 1m 20s	remaining: 18.7s
# 1624:	total: 1m 20s	remaining: 18.7s
# 1625:	total: 1m 20s	remaining: 18.6s
# 1626:	total: 1m 20s	remaining: 18.6s
# 1627:	total: 1m 21s	remaining: 18.5s
# 1628:	total: 1m 21s	remaining: 18.5s
# 1629:	total: 1m 21s	remaining: 18.4s
# 1630:	total: 1m 21s	remaining: 18.4s
# 1631:	total: 1m 21s	remaining: 18.3s
# 1632:	total: 1m 21s	remaining: 18.3s
# 1633:	total: 1m 21s	remaining: 18.2s
# 1634:	total: 1m 21s	remaining: 18.2s
# 1635:	total: 1m 21s	remaining: 18.1s
# 1636:	total: 1m 21s	remaining: 18.1s
# 1637:	total: 1m 21s	remaining: 18s
# 1638:	total: 1m 21s	remaining: 17.9s
# 1639:	total: 1m 21s	remaining: 17.9s
# 1640:	total: 1m 21s	remaining: 17.8s
# 1641:	total: 1m 21s	remaining: 17.8s
# 1642:	total: 1m 21s	remaining: 17.7s
# 1643:	total: 1m 21s	remaining: 17.7s
# 1644:	total: 1m 21s	remaining: 17.6s
# 1645:	total: 1m 21s	remaining: 17.6s
# 1646:	total: 1m 21s	remaining: 17.5s
# 1647:	total: 1m 21s	remaining: 17.5s
# 1648:	total: 1m 21s	remaining: 17.4s
# 1649:	total: 1m 21s	remaining: 17.4s
# 1650:	total: 1m 21s	remaining: 17.3s
# 1651:	total: 1m 22s	remaining: 17.3s
# 1652:	total: 1m 22s	remaining: 17.2s
# 1653:	total: 1m 22s	remaining: 17.2s
# 1654:	total: 1m 22s	remaining: 17.1s
# 1655:	total: 1m 22s	remaining: 17.1s
# 1656:	total: 1m 22s	remaining: 17s
# 1657:	total: 1m 22s	remaining: 17s
# 1658:	total: 1m 22s	remaining: 16.9s
# 1659:	total: 1m 22s	remaining: 16.9s
# 1660:	total: 1m 22s	remaining: 16.8s
# 1661:	total: 1m 22s	remaining: 16.8s
# 1662:	total: 1m 22s	remaining: 16.7s
# 1663:	total: 1m 22s	remaining: 16.7s
# 1664:	total: 1m 22s	remaining: 16.6s
# 1665:	total: 1m 22s	remaining: 16.6s
# 1666:	total: 1m 22s	remaining: 16.5s
# 1667:	total: 1m 22s	remaining: 16.5s
# 1668:	total: 1m 22s	remaining: 16.4s
# 1669:	total: 1m 22s	remaining: 16.4s
# 1670:	total: 1m 22s	remaining: 16.3s
# 1671:	total: 1m 22s	remaining: 16.2s
# 1672:	total: 1m 22s	remaining: 16.2s
# 1673:	total: 1m 22s	remaining: 16.1s
# 1674:	total: 1m 22s	remaining: 16.1s
# 1675:	total: 1m 22s	remaining: 16s
# 1676:	total: 1m 23s	remaining: 16s
# 1677:	total: 1m 23s	remaining: 15.9s
# 1678:	total: 1m 23s	remaining: 15.9s
# 1679:	total: 1m 23s	remaining: 15.8s
# 1680:	total: 1m 23s	remaining: 15.8s
# 1681:	total: 1m 23s	remaining: 15.7s
# 1682:	total: 1m 23s	remaining: 15.7s
# 1683:	total: 1m 23s	remaining: 15.6s
# 1684:	total: 1m 23s	remaining: 15.6s
# 1685:	total: 1m 23s	remaining: 15.5s
# 1686:	total: 1m 23s	remaining: 15.5s
# 1687:	total: 1m 23s	remaining: 15.4s
# 1688:	total: 1m 23s	remaining: 15.4s
# 1689:	total: 1m 23s	remaining: 15.3s
# 1690:	total: 1m 23s	remaining: 15.3s
# 1691:	total: 1m 23s	remaining: 15.2s
# 1692:	total: 1m 23s	remaining: 15.2s
# 1693:	total: 1m 23s	remaining: 15.1s
# 1694:	total: 1m 23s	remaining: 15.1s
# 1695:	total: 1m 23s	remaining: 15s
# 1696:	total: 1m 23s	remaining: 15s
# 1697:	total: 1m 23s	remaining: 14.9s
# 1698:	total: 1m 23s	remaining: 14.9s
# 1699:	total: 1m 24s	remaining: 14.8s
# 1700:	total: 1m 24s	remaining: 14.8s
# 1701:	total: 1m 24s	remaining: 14.7s
# 1702:	total: 1m 24s	remaining: 14.7s
# 1703:	total: 1m 24s	remaining: 14.6s
# 1704:	total: 1m 24s	remaining: 14.6s
# 1705:	total: 1m 24s	remaining: 14.5s
# 1706:	total: 1m 24s	remaining: 14.5s
# 1707:	total: 1m 24s	remaining: 14.4s
# 1708:	total: 1m 24s	remaining: 14.4s
# 1709:	total: 1m 24s	remaining: 14.4s
# 1710:	total: 1m 24s	remaining: 14.3s
# 1711:	total: 1m 24s	remaining: 14.3s
# 1712:	total: 1m 24s	remaining: 14.2s
# 1713:	total: 1m 24s	remaining: 14.2s
# 1714:	total: 1m 25s	remaining: 14.1s
# 1715:	total: 1m 25s	remaining: 14.1s
# 1716:	total: 1m 25s	remaining: 14.1s
# 1717:	total: 1m 25s	remaining: 14s
# 1718:	total: 1m 25s	remaining: 14s
# 1719:	total: 1m 25s	remaining: 13.9s
# 1720:	total: 1m 25s	remaining: 13.9s
# 1721:	total: 1m 25s	remaining: 13.8s
# 1722:	total: 1m 25s	remaining: 13.8s
# 1723:	total: 1m 25s	remaining: 13.7s
# 1724:	total: 1m 25s	remaining: 13.7s
# 1725:	total: 1m 26s	remaining: 13.7s
# 1726:	total: 1m 26s	remaining: 13.6s
# 1727:	total: 1m 26s	remaining: 13.6s
# 1728:	total: 1m 26s	remaining: 13.5s
# 1729:	total: 1m 26s	remaining: 13.5s
# 1730:	total: 1m 26s	remaining: 13.4s
# 1731:	total: 1m 26s	remaining: 13.4s
# 1732:	total: 1m 26s	remaining: 13.4s
# 1733:	total: 1m 26s	remaining: 13.3s
# 1734:	total: 1m 26s	remaining: 13.3s
# 1735:	total: 1m 26s	remaining: 13.2s
# 1736:	total: 1m 27s	remaining: 13.2s
# 1737:	total: 1m 27s	remaining: 13.1s
# 1738:	total: 1m 27s	remaining: 13.1s
# 1739:	total: 1m 27s	remaining: 13s
# 1740:	total: 1m 27s	remaining: 13s
# 1741:	total: 1m 27s	remaining: 13s
# 1742:	total: 1m 27s	remaining: 12.9s
# 1743:	total: 1m 27s	remaining: 12.9s
# 1744:	total: 1m 27s	remaining: 12.8s
# 1745:	total: 1m 27s	remaining: 12.8s
# 1746:	total: 1m 27s	remaining: 12.7s
# 1747:	total: 1m 27s	remaining: 12.7s
# 1748:	total: 1m 27s	remaining: 12.6s
# 1749:	total: 1m 28s	remaining: 12.6s
# 1750:	total: 1m 28s	remaining: 12.5s
# 1751:	total: 1m 28s	remaining: 12.5s
# 1752:	total: 1m 28s	remaining: 12.4s
# 1753:	total: 1m 28s	remaining: 12.4s
# 1754:	total: 1m 28s	remaining: 12.3s
# 1755:	total: 1m 28s	remaining: 12.3s
# 1756:	total: 1m 28s	remaining: 12.2s
# 1757:	total: 1m 28s	remaining: 12.2s
# 1758:	total: 1m 28s	remaining: 12.1s
# 1759:	total: 1m 28s	remaining: 12.1s
# 1760:	total: 1m 28s	remaining: 12s
# 1761:	total: 1m 28s	remaining: 12s
# 1762:	total: 1m 28s	remaining: 11.9s
# 1763:	total: 1m 28s	remaining: 11.9s
# 1764:	total: 1m 28s	remaining: 11.8s
# 1765:	total: 1m 28s	remaining: 11.8s
# 1766:	total: 1m 28s	remaining: 11.7s
# 1767:	total: 1m 28s	remaining: 11.7s
# 1768:	total: 1m 28s	remaining: 11.6s
# 1769:	total: 1m 28s	remaining: 11.6s
# 1770:	total: 1m 28s	remaining: 11.5s
# 1771:	total: 1m 28s	remaining: 11.4s
# 1772:	total: 1m 29s	remaining: 11.4s
# 1773:	total: 1m 29s	remaining: 11.3s
# 1774:	total: 1m 29s	remaining: 11.3s
# 1775:	total: 1m 29s	remaining: 11.2s
# 1776:	total: 1m 29s	remaining: 11.2s
# 1777:	total: 1m 29s	remaining: 11.1s
# 1778:	total: 1m 29s	remaining: 11.1s
# 1779:	total: 1m 29s	remaining: 11s
# 1780:	total: 1m 29s	remaining: 11s
# 1781:	total: 1m 29s	remaining: 10.9s
# 1782:	total: 1m 29s	remaining: 10.9s
# 1783:	total: 1m 29s	remaining: 10.8s
# 1784:	total: 1m 29s	remaining: 10.8s
# 1785:	total: 1m 29s	remaining: 10.7s
# 1786:	total: 1m 29s	remaining: 10.7s
# 1787:	total: 1m 29s	remaining: 10.6s
# 1788:	total: 1m 29s	remaining: 10.6s
# 1789:	total: 1m 29s	remaining: 10.5s
# 1790:	total: 1m 29s	remaining: 10.5s
# 1791:	total: 1m 29s	remaining: 10.4s
# 1792:	total: 1m 29s	remaining: 10.4s
# 1793:	total: 1m 29s	remaining: 10.3s
# 1794:	total: 1m 29s	remaining: 10.3s
# 1795:	total: 1m 29s	remaining: 10.2s
# 1796:	total: 1m 30s	remaining: 10.2s
# 1797:	total: 1m 30s	remaining: 10.1s
# 1798:	total: 1m 30s	remaining: 10.1s
# 1799:	total: 1m 30s	remaining: 10s
# 1800:	total: 1m 30s	remaining: 9.96s
# 1801:	total: 1m 30s	remaining: 9.91s
# 1802:	total: 1m 30s	remaining: 9.86s
# 1803:	total: 1m 30s	remaining: 9.81s
# 1804:	total: 1m 30s	remaining: 9.76s
# 1805:	total: 1m 30s	remaining: 9.71s
# 1806:	total: 1m 30s	remaining: 9.66s
# 1807:	total: 1m 30s	remaining: 9.61s
# 1808:	total: 1m 30s	remaining: 9.55s
# 1809:	total: 1m 30s	remaining: 9.5s
# 1810:	total: 1m 30s	remaining: 9.45s
# 1811:	total: 1m 30s	remaining: 9.4s
# 1812:	total: 1m 30s	remaining: 9.35s
# 1813:	total: 1m 30s	remaining: 9.3s
# 1814:	total: 1m 30s	remaining: 9.25s
# 1815:	total: 1m 30s	remaining: 9.2s
# 1816:	total: 1m 30s	remaining: 9.15s
# 1817:	total: 1m 30s	remaining: 9.1s
# 1818:	total: 1m 30s	remaining: 9.04s
# 1819:	total: 1m 30s	remaining: 8.99s
# 1820:	total: 1m 30s	remaining: 8.94s
# 1821:	total: 1m 31s	remaining: 8.89s
# 1822:	total: 1m 31s	remaining: 8.84s
# 1823:	total: 1m 31s	remaining: 8.79s
# 1824:	total: 1m 31s	remaining: 8.74s
# 1825:	total: 1m 31s	remaining: 8.69s
# 1826:	total: 1m 31s	remaining: 8.64s
# 1827:	total: 1m 31s	remaining: 8.59s
# 1828:	total: 1m 31s	remaining: 8.54s
# 1829:	total: 1m 31s	remaining: 8.49s
# 1830:	total: 1m 31s	remaining: 8.44s
# 1831:	total: 1m 31s	remaining: 8.38s
# 1832:	total: 1m 31s	remaining: 8.33s
# 1833:	total: 1m 31s	remaining: 8.28s
# 1834:	total: 1m 31s	remaining: 8.23s
# 1835:	total: 1m 31s	remaining: 8.18s
# 1836:	total: 1m 31s	remaining: 8.13s
# 1837:	total: 1m 31s	remaining: 8.08s
# 1838:	total: 1m 31s	remaining: 8.03s
# 1839:	total: 1m 31s	remaining: 7.98s
# 1840:	total: 1m 31s	remaining: 7.93s
# 1841:	total: 1m 31s	remaining: 7.88s
# 1842:	total: 1m 31s	remaining: 7.83s
# 1843:	total: 1m 31s	remaining: 7.77s
# 1844:	total: 1m 31s	remaining: 7.72s
# 1845:	total: 1m 31s	remaining: 7.67s
# 1846:	total: 1m 32s	remaining: 7.62s
# 1847:	total: 1m 32s	remaining: 7.57s
# 1848:	total: 1m 32s	remaining: 7.52s
# 1849:	total: 1m 32s	remaining: 7.47s
# 1850:	total: 1m 32s	remaining: 7.42s
# 1851:	total: 1m 32s	remaining: 7.37s
# 1852:	total: 1m 32s	remaining: 7.32s
# 1853:	total: 1m 32s	remaining: 7.27s
# 1854:	total: 1m 32s	remaining: 7.22s
# 1855:	total: 1m 32s	remaining: 7.17s
# 1856:	total: 1m 32s	remaining: 7.12s
# 1857:	total: 1m 32s	remaining: 7.07s
# 1858:	total: 1m 32s	remaining: 7.02s
# 1859:	total: 1m 32s	remaining: 6.97s
# 1860:	total: 1m 32s	remaining: 6.92s
# 1861:	total: 1m 32s	remaining: 6.87s
# 1862:	total: 1m 32s	remaining: 6.81s
# 1863:	total: 1m 32s	remaining: 6.76s
# 1864:	total: 1m 32s	remaining: 6.71s
# 1865:	total: 1m 32s	remaining: 6.66s
# 1866:	total: 1m 32s	remaining: 6.61s
# 1867:	total: 1m 32s	remaining: 6.56s
# 1868:	total: 1m 32s	remaining: 6.51s
# 1869:	total: 1m 32s	remaining: 6.46s
# 1870:	total: 1m 32s	remaining: 6.41s
# 1871:	total: 1m 33s	remaining: 6.36s
# 1872:	total: 1m 33s	remaining: 6.31s
# 1873:	total: 1m 33s	remaining: 6.26s
# 1874:	total: 1m 33s	remaining: 6.21s
# 1875:	total: 1m 33s	remaining: 6.16s
# 1876:	total: 1m 33s	remaining: 6.11s
# 1877:	total: 1m 33s	remaining: 6.06s
# 1878:	total: 1m 33s	remaining: 6.01s
# 1879:	total: 1m 33s	remaining: 5.96s
# 1880:	total: 1m 33s	remaining: 5.91s
# 1881:	total: 1m 33s	remaining: 5.86s
# 1882:	total: 1m 33s	remaining: 5.81s
# 1883:	total: 1m 33s	remaining: 5.76s
# 1884:	total: 1m 33s	remaining: 5.71s
# 1885:	total: 1m 33s	remaining: 5.66s
# 1886:	total: 1m 33s	remaining: 5.61s
# 1887:	total: 1m 33s	remaining: 5.56s
# 1888:	total: 1m 33s	remaining: 5.51s
# 1889:	total: 1m 33s	remaining: 5.46s
# 1890:	total: 1m 33s	remaining: 5.41s
# 1891:	total: 1m 33s	remaining: 5.36s
# 1892:	total: 1m 33s	remaining: 5.31s
# 1893:	total: 1m 33s	remaining: 5.26s
# 1894:	total: 1m 33s	remaining: 5.21s
# 1895:	total: 1m 34s	remaining: 5.16s
# 1896:	total: 1m 34s	remaining: 5.11s
# 1897:	total: 1m 34s	remaining: 5.06s
# 1898:	total: 1m 34s	remaining: 5s
# 1899:	total: 1m 34s	remaining: 4.96s
# 1900:	total: 1m 34s	remaining: 4.91s
# 1901:	total: 1m 34s	remaining: 4.86s
# 1902:	total: 1m 34s	remaining: 4.81s
# 1903:	total: 1m 34s	remaining: 4.76s
# 1904:	total: 1m 34s	remaining: 4.71s
# 1905:	total: 1m 34s	remaining: 4.66s
# 1906:	total: 1m 34s	remaining: 4.61s
# 1907:	total: 1m 34s	remaining: 4.56s
# 1908:	total: 1m 34s	remaining: 4.51s
# 1909:	total: 1m 34s	remaining: 4.46s
# 1910:	total: 1m 34s	remaining: 4.41s
# 1911:	total: 1m 34s	remaining: 4.36s
# 1912:	total: 1m 34s	remaining: 4.31s
# 1913:	total: 1m 34s	remaining: 4.26s
# 1914:	total: 1m 34s	remaining: 4.21s
# 1915:	total: 1m 34s	remaining: 4.16s
# 1916:	total: 1m 34s	remaining: 4.11s
# 1917:	total: 1m 34s	remaining: 4.06s
# 1918:	total: 1m 34s	remaining: 4.01s
# 1919:	total: 1m 34s	remaining: 3.96s
# 1920:	total: 1m 35s	remaining: 3.91s
# 1921:	total: 1m 35s	remaining: 3.86s
# 1922:	total: 1m 35s	remaining: 3.81s
# 1923:	total: 1m 35s	remaining: 3.76s
# 1924:	total: 1m 35s	remaining: 3.71s
# 1925:	total: 1m 35s	remaining: 3.66s
# 1926:	total: 1m 35s	remaining: 3.61s
# 1927:	total: 1m 35s	remaining: 3.56s
# 1928:	total: 1m 35s	remaining: 3.51s
# 1929:	total: 1m 35s	remaining: 3.46s
# 1930:	total: 1m 35s	remaining: 3.41s
# 1931:	total: 1m 35s	remaining: 3.36s
# 1932:	total: 1m 35s	remaining: 3.31s
# 1933:	total: 1m 35s	remaining: 3.26s
# 1934:	total: 1m 35s	remaining: 3.21s
# 1935:	total: 1m 35s	remaining: 3.16s
# 1936:	total: 1m 35s	remaining: 3.11s
# 1937:	total: 1m 35s	remaining: 3.06s
# 1938:	total: 1m 35s	remaining: 3.01s
# 1939:	total: 1m 35s	remaining: 2.96s
# 1940:	total: 1m 35s	remaining: 2.91s
# 1941:	total: 1m 35s	remaining: 2.86s
# 1942:	total: 1m 35s	remaining: 2.81s
# 1943:	total: 1m 35s	remaining: 2.76s
# 1944:	total: 1m 35s	remaining: 2.71s
# 1945:	total: 1m 36s	remaining: 2.66s
# 1946:	total: 1m 36s	remaining: 2.62s
# 1947:	total: 1m 36s	remaining: 2.56s
# 1948:	total: 1m 36s	remaining: 2.52s
# 1949:	total: 1m 36s	remaining: 2.47s
# 1950:	total: 1m 36s	remaining: 2.42s
# 1951:	total: 1m 36s	remaining: 2.37s
# 1952:	total: 1m 36s	remaining: 2.32s
# 1953:	total: 1m 36s	remaining: 2.27s
# 1954:	total: 1m 36s	remaining: 2.22s
# 1955:	total: 1m 36s	remaining: 2.17s
# 1956:	total: 1m 36s	remaining: 2.12s
# 1957:	total: 1m 36s	remaining: 2.07s
# 1958:	total: 1m 36s	remaining: 2.02s
# 1959:	total: 1m 36s	remaining: 1.97s
# 1960:	total: 1m 36s	remaining: 1.92s
# 1961:	total: 1m 36s	remaining: 1.87s
# 1962:	total: 1m 36s	remaining: 1.82s
# 1963:	total: 1m 36s	remaining: 1.77s
# 1964:	total: 1m 36s	remaining: 1.72s
# 1965:	total: 1m 36s	remaining: 1.67s
# 1966:	total: 1m 36s	remaining: 1.63s
# 1967:	total: 1m 36s	remaining: 1.58s
# 1968:	total: 1m 36s	remaining: 1.53s
# 1969:	total: 1m 37s	remaining: 1.48s
# 1970:	total: 1m 37s	remaining: 1.43s
# 1971:	total: 1m 37s	remaining: 1.38s
# 1972:	total: 1m 37s	remaining: 1.33s
# 1973:	total: 1m 37s	remaining: 1.28s
# 1974:	total: 1m 37s	remaining: 1.23s
# 1975:	total: 1m 37s	remaining: 1.18s
# 1976:	total: 1m 37s	remaining: 1.13s
# 1977:	total: 1m 37s	remaining: 1.08s
# 1978:	total: 1m 37s	remaining: 1.03s
# 1979:	total: 1m 37s	remaining: 984ms
# 1980:	total: 1m 37s	remaining: 935ms
# 1981:	total: 1m 37s	remaining: 886ms
# 1982:	total: 1m 37s	remaining: 836ms
# 1983:	total: 1m 37s	remaining: 787ms
# 1984:	total: 1m 37s	remaining: 738ms
# 1985:	total: 1m 37s	remaining: 689ms
# 1986:	total: 1m 37s	remaining: 639ms
# 1987:	total: 1m 37s	remaining: 590ms
# 1988:	total: 1m 37s	remaining: 541ms
# 1989:	total: 1m 37s	remaining: 492ms
# 1990:	total: 1m 37s	remaining: 443ms
# 1991:	total: 1m 38s	remaining: 394ms
# 1992:	total: 1m 38s	remaining: 345ms
# 1993:	total: 1m 38s	remaining: 296ms
# 1994:	total: 1m 38s	remaining: 246ms
# 1995:	total: 1m 38s	remaining: 197ms
# 1996:	total: 1m 38s	remaining: 148ms
# 1997:	total: 1m 38s	remaining: 98.7ms
# 1998:	total: 1m 38s	remaining: 49.4ms
# 1999:	total: 1m 38s	remaining: 0us

# %%
y_pred = cat.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[21166  1551]
#  [ 3608  2767]]
# 0.8226660250240616
#               precision    recall  f1-score   support
#
#        False       0.85      0.93      0.89     22717
#         True       0.64      0.43      0.52      6375
#
#     accuracy                           0.82     29092
#    macro avg       0.75      0.68      0.70     29092
# weighted avg       0.81      0.82      0.81     29092

# %%
metrics.RocCurveDisplay.from_estimator(cat, X_test, y_test)

# %%
metrics.roc_auc_score(y_test, y_pred, average=None)
# Out:
# 0.6828821777247237

# %%
rf=RandomForestClassifier()
rf.fit(X_train_res,y_train_res)
# Out:
# RandomForestClassifier()

# %%
y_pred1 = rf.predict(X_test)
print(confusion_matrix(y_test,y_pred1))
print(accuracy_score(y_test,y_pred1))
print(classification_report(y_test,y_pred1))
# Out:
# [[19757  2960]
#  [ 3029  3346]]
# 0.794135844905816
#               precision    recall  f1-score   support
#
#        False       0.87      0.87      0.87     22717
#         True       0.53      0.52      0.53      6375
#
#     accuracy                           0.79     29092
#    macro avg       0.70      0.70      0.70     29092
# weighted avg       0.79      0.79      0.79     29092

# %%
metrics.RocCurveDisplay.from_estimator(rf, X_test, y_test)
metrics.roc_auc_score(y_test, y_pred1, average=None)
# Out:
# 0.6972819249987269

# %%
logreg = LogisticRegression()
logreg.fit(X_train_res, y_train_res)
# Out:
# LogisticRegression()

# %%
y_pred2 = logreg.predict(X_test)
print(confusion_matrix(y_test,y_pred2))
print(accuracy_score(y_test,y_pred2))
print(classification_report(y_test,y_pred2))
# Out:
# [[17443  5274]
#  [ 2139  4236]]
# 0.7451876804619827
#               precision    recall  f1-score   support
#
#        False       0.89      0.77      0.82     22717
#         True       0.45      0.66      0.53      6375
#
#     accuracy                           0.75     29092
#    macro avg       0.67      0.72      0.68     29092
# weighted avg       0.79      0.75      0.76     29092

# %%
metrics.RocCurveDisplay.from_estimator(logreg, X_test, y_test)
metrics.roc_auc_score(y_test, y_pred2, average=None)
# Out:
# 0.7161548257459431

# %%
gnb = GaussianNB()
gnb.fit(X_train_res, y_train_res)
# Out:
# GaussianNB()

# %%
y_pred3 = gnb.predict(X_test)
print(confusion_matrix(y_test,y_pred3))
print(accuracy_score(y_test,y_pred3))
print(classification_report(y_test,y_pred3))
# Out:
# [[18136  4581]
#  [ 2616  3759]]
# 0.7526124020349237
#               precision    recall  f1-score   support
#
#        False       0.87      0.80      0.83     22717
#         True       0.45      0.59      0.51      6375
#
#     accuracy                           0.75     29092
#    macro avg       0.66      0.69      0.67     29092
# weighted avg       0.78      0.75      0.76     29092

# %%
metrics.RocCurveDisplay.from_estimator(gnb, X_test, y_test)
metrics.roc_auc_score(y_test, y_pred3, average=None)
# Out:
# 0.693995955348288

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train_res, y_train_res)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred4 = knn.predict(X_test)
print(confusion_matrix(y_test,y_pred4))
print(accuracy_score(y_test,y_pred4))
print(classification_report(y_test,y_pred4))
# Out:
# [[16851  5866]
#  [ 2566  3809]]
# 0.7101608689674137
#               precision    recall  f1-score   support
#
#        False       0.87      0.74      0.80     22717
#         True       0.39      0.60      0.47      6375
#
#     accuracy                           0.71     29092
#    macro avg       0.63      0.67      0.64     29092
# weighted avg       0.76      0.71      0.73     29092

# %%
metrics.RocCurveDisplay.from_estimator(knn, X_test, y_test)
metrics.roc_auc_score(y_test, y_pred4, average=None)
# Out:
# 0.6696347401574532

# %%
xgb = XGBClassifier()
xgb.fit(X_train_res, y_train_res)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_pred6 = xgb.predict(X_test)
print(confusion_matrix(y_test,y_pred6))
print(accuracy_score(y_test,y_pred6))
print(classification_report(y_test,y_pred6))
# Out:
# [[19753  2964]
#  [ 2913  3462]]
# 0.7979857005362299
#               precision    recall  f1-score   support
#
#        False       0.87      0.87      0.87     22717
#         True       0.54      0.54      0.54      6375
#
#     accuracy                           0.80     29092
#    macro avg       0.71      0.71      0.71     29092
# weighted avg       0.80      0.80      0.80     29092

# %%
metrics.RocCurveDisplay.from_estimator(xgb, X_test, y_test)
metrics.roc_auc_score(y_test, y_pred6, average=None)
# Out:
# 0.7062919244204263

# %%
#joblib.dump(rf, "rf.pkl")
#joblib.dump(cat, "cat.pkl")
#joblib.dump(gnb, "gnb.pkl")
#joblib.dump(knn, "knn.pkl")
joblib.dump(logreg, "logreg.pkl")
joblib.dump(xgb, "xgb.pkl")
# Out:
# ['xgb.pkl']

# %%
joblib.dump(logreg, "logreg.pkl")

# %%
svc = SVC()
svc.fit(X_train_res, y_train_res)

# %%
y_pred5 = svc.predict(X_test)
print(confusion_matrix(y_test,y_pred5))
print(accuracy_score(y_test,y_pred5))
print(classification_report(y_test,y_pred5))

# %%
metrics.RocCurveDisplay.from_estimator(svc, X_test, y_test)
metrics.roc_auc_score(y_test, y_pred5, average=None)

# %%
joblib.dump(svc, "svc.pkl")

# %%
joblib.dump(logreg, "logreg.pkl")
